# %% [markdown]
# https://en.wikipedia.org/wiki/Rank-maximal_allocation

# %%
# !pipenv install scipy numpy pandas seaborn xlrd openpyxl
# %config Completer.use_jedi = False

# %%
import numpy as np
import pandas as pd
import scipy.optimize

import json

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

import seaborn as sns
sns.set()

# %%
# Hungarian algorithm (Kuhn-Munkres) for solving the linear sum assignment
# problem. Taken from scikit-learn. Based on original code by Brian Clapper,
# adapted to NumPy by Gael Varoquaux.
# Further improvements by Ben Root, Vlad Niculae and Lars Buitinck.
#
# Copyright (c) 2008 Brian M. Clapper <bmc@clapper.org>, Gael Varoquaux
# Author: Brian M. Clapper, Gael Varoquaux
# License: 3-clause BSD

def linear_sum_assignment(cost_matrix):
    """Solve the linear sum assignment problem.

    The linear sum assignment problem is also known as minimum weight matching
    in bipartite graphs. A problem instance is described by a matrix C, where
    each C[i,j] is the cost of matching vertex i of the first partite set
    (a "worker") and vertex j of the second set (a "job"). The goal is to find
    a complete assignment of workers to jobs of minimal cost.

    Formally, let X be a boolean matrix where :math:`X[i,j] = 1` iff row i is
    assigned to column j. Then the optimal assignment has cost

    .. math::
        \min \sum_i \sum_j C_{i,j} X_{i,j}

    s.t. each row is assignment to at most one column, and each column to at
    most one row.

    This function can also solve a generalization of the classic assignment
    problem where the cost matrix is rectangular. If it has more rows than
    columns, then not every row needs to be assigned to a column, and vice
    versa.

    The method used is the Hungarian algorithm, also known as the Munkres or
    Kuhn-Munkres algorithm.

    Parameters
    ----------
    cost_matrix : array
        The cost matrix of the bipartite graph.

    Returns
    -------
    row_ind, col_ind : array
        An array of row indices and one of corresponding column indices giving
        the optimal assignment. The cost of the assignment can be computed
        as ``cost_matrix[row_ind, col_ind].sum()``. The row indices will be
        sorted; in the case of a square cost matrix they will be equal to
        ``numpy.arange(cost_matrix.shape[0])``.

    Notes
    -----
    .. versionadded:: 0.17.0

    Examples
    --------
    >>> cost = np.array([[4, 1, 3], [2, 0, 5], [3, 2, 2]])
    >>> from scipy.optimize import linear_sum_assignment
    >>> row_ind, col_ind = linear_sum_assignment(cost)
    >>> col_ind
    array([1, 0, 2])
    >>> cost[row_ind, col_ind].sum()
    5

    References
    ----------
    1. http://csclab.murraystate.edu/bob.pilgrim/445/munkres.html

    2. Harold W. Kuhn. The Hungarian Method for the assignment problem.
       *Naval Research Logistics Quarterly*, 2:83-97, 1955.

    3. Harold W. Kuhn. Variants of the Hungarian method for assignment
       problems. *Naval Research Logistics Quarterly*, 3: 253-258, 1956.

    4. Munkres, J. Algorithms for the Assignment and Transportation Problems.
       *J. SIAM*, 5(1):32-38, March, 1957.

    5. https://en.wikipedia.org/wiki/Hungarian_algorithm
    """
    cost_matrix = np.asarray(cost_matrix)
    if len(cost_matrix.shape) != 2:
        raise ValueError("expected a matrix (2-d array), got a %r array"
                         % (cost_matrix.shape,))

    # The algorithm expects more columns than rows in the cost matrix.
    if cost_matrix.shape[1] < cost_matrix.shape[0]:
        cost_matrix = cost_matrix.T
        transposed = True
    else:
        transposed = False

    state = _Hungary(cost_matrix)

    # No need to bother with assignments if one of the dimensions
    # of the cost matrix is zero-length.
    step = None if 0 in cost_matrix.shape else _step1

    while step is not None:
        step = step(state)

    if transposed:
        marked = state.marked.T
    else:
        marked = state.marked
    return np.where(marked == 1)


class _Hungary(object):
    """State of the Hungarian algorithm.

    Parameters
    ----------
    cost_matrix : 2D matrix
        The cost matrix. Must have shape[1] >= shape[0].
    """

    def __init__(self, cost_matrix):
        self.C = cost_matrix.copy()

        n, m = self.C.shape
        self.row_uncovered = np.ones(n, dtype=bool)
        self.col_uncovered = np.ones(m, dtype=bool)
        self.Z0_r = 0
        self.Z0_c = 0
        self.path = np.zeros((n + m, 2), dtype=int)
        self.marked = np.zeros((n, m), dtype=int)

    def _clear_covers(self):
        """Clear all covered matrix cells"""
        self.row_uncovered[:] = True
        self.col_uncovered[:] = True


# Individual steps of the algorithm follow, as a state machine: they return
# the next step to be taken (function to be called), if any.

def _step1(state):
    """Steps 1 and 2 in the Wikipedia page."""

    # Step 1: For each row of the matrix, find the smallest element and
    # subtract it from every element in its row.
    state.C -= state.C.min(axis=1)[:, np.newaxis]
    # Step 2: Find a zero (Z) in the resulting matrix. If there is no
    # starred zero in its row or column, star Z. Repeat for each element
    # in the matrix.
    for i, j in zip(*np.where(state.C == 0)):
        if state.col_uncovered[j] and state.row_uncovered[i]:
            state.marked[i, j] = 1
            state.col_uncovered[j] = False
            state.row_uncovered[i] = False

    state._clear_covers()
    return _step3


def _step3(state):
    """
    Cover each column containing a starred zero. If n columns are covered,
    the starred zeros describe a complete set of unique assignments.
    In this case, Go to DONE, otherwise, Go to Step 4.
    """
    marked = (state.marked == 1)
    state.col_uncovered[np.any(marked, axis=0)] = False

    if marked.sum() < state.C.shape[0]:
        return _step4


def _step4(state):
    """
    Find a noncovered zero and prime it. If there is no starred zero
    in the row containing this primed zero, Go to Step 5. Otherwise,
    cover this row and uncover the column containing the starred
    zero. Continue in this manner until there are no uncovered zeros
    left. Save the smallest uncovered value and Go to Step 6.
    """
    # We convert to int as numpy operations are faster on int
    C = (state.C == 0).astype(int)
    covered_C = C * state.row_uncovered[:, np.newaxis]
    covered_C *= np.asarray(state.col_uncovered, dtype=int)
    n = state.C.shape[0]
    m = state.C.shape[1]

    while True:
        # Find an uncovered zero
        row, col = np.unravel_index(np.argmax(covered_C), (n, m))
        if covered_C[row, col] == 0:
            return _step6
        else:
            state.marked[row, col] = 2
            # Find the first starred element in the row
            star_col = np.argmax(state.marked[row] == 1)
            if state.marked[row, star_col] != 1:
                # Could not find one
                state.Z0_r = row
                state.Z0_c = col
                return _step5
            else:
                col = star_col
                state.row_uncovered[row] = False
                state.col_uncovered[col] = True
                covered_C[:, col] = C[:, col] * (
                    np.asarray(state.row_uncovered, dtype=int))
                covered_C[row] = 0


def _step5(state):
    """
    Construct a series of alternating primed and starred zeros as follows.
    Let Z0 represent the uncovered primed zero found in Step 4.
    Let Z1 denote the starred zero in the column of Z0 (if any).
    Let Z2 denote the primed zero in the row of Z1 (there will always be one).
    Continue until the series terminates at a primed zero that has no starred
    zero in its column. Unstar each starred zero of the series, star each
    primed zero of the series, erase all primes and uncover every line in the
    matrix. Return to Step 3
    """
    count = 0
    path = state.path
    path[count, 0] = state.Z0_r
    path[count, 1] = state.Z0_c

    while True:
        # Find the first starred element in the col defined by
        # the path.
        row = np.argmax(state.marked[:, path[count, 1]] == 1)
        if state.marked[row, path[count, 1]] != 1:
            # Could not find one
            break
        else:
            count += 1
            path[count, 0] = row
            path[count, 1] = path[count - 1, 1]

        # Find the first prime element in the row defined by the
        # first path step
        col = np.argmax(state.marked[path[count, 0]] == 2)
        if state.marked[row, col] != 2:
            col = -1
        count += 1
        path[count, 0] = path[count - 1, 0]
        path[count, 1] = col

    # Convert paths
    for i in range(count + 1):
        if state.marked[path[i, 0], path[i, 1]] == 1:
            state.marked[path[i, 0], path[i, 1]] = 0
        else:
            state.marked[path[i, 0], path[i, 1]] = 1

    state._clear_covers()
    # Erase all prime markings
    state.marked[state.marked == 2] = 0
    return _step3


def _step6(state):
    """
    Add the value found in Step 4 to every element of each covered row,
    and subtract it from every element of each uncovered column.
    Return to Step 4 without altering any stars, primes, or covered lines.
    """
    # the smallest uncovered value in the matrix
    if np.any(state.row_uncovered) and np.any(state.col_uncovered):
        minval = np.min(state.C[state.row_uncovered], axis=0)
        minval = np.min(minval[state.col_uncovered])
        state.C[~state.row_uncovered] += minval
        state.C[:, state.col_uncovered] -= minval
    return _step4

# %% [markdown]
# We have $n$ applicants to $m$ jobs

# %%
class Profile:
    @staticmethod
    def compute_profile(ranks, applicants, jobs):
        """
        Returns the profile of a matching of applicants to jobs given the overall ranks.

            Parameters:
                ranks (np.ndarray): an n x m matrix of rankings, where ranks[i,j] is the rank of applicant i for job j
                applicants (np.ndarray): an n-vector of applicant indices
                jobs (np.ndarray): an m-vector of selected jobs corresponding to each applicant, so that jobs[i] is the choice of job for applicant[i]

            Returns:
                profile (np.ndarray): an m-vector where profile[i] is the number of applicants who were assigned their i'th pick of job
        """
        
        # applicants may be in an order different than [0, 1, 2, ...]
        selected_ranks = ranks[applicants]
        (n, m)  = selected_ranks.shape

        # Argsort turns an array of ranks into a list of jobs, ranked
        argsort = np.argsort(selected_ranks, axis=1)

        profile = np.zeros(m)

        for j in range(m):
            # Count how many jobs ranked 1st by applicants are equal to the jobs assigned.
            # Then, count how many jobs ranked 2nd were equal to the jobs assigned. etc.
            profile[j] = (argsort[:, j] == jobs).sum()

        # we should have assigned one job for each applicant.
        assert profile.sum() == n
        return profile
    
    @staticmethod
    def compare_profiles(a, b):
        """
        Used to compare profiles in lexicographic order.

            Parameters:
                a (np.ndarray): a profile for a matching. An m-vector where profile[i] is the number of applicants who were assigned their i'th pick of job
                b (np.ndarray): a profile for a matching.

            Returns:
                1  if b < a
                -1 if a < b
                0  if a = b
        """
        where = np.where( (a>b) != (a<b) )
        if where[0].size == 0:
            # they are identical
            return 0

        idx = where[0][0]

        if a[idx] < b[idx]:
            return -1
        elif a[idx] > b[idx]:
            return 1
        
    @staticmethod
    def compute_profile_from_result(ranks, matching):
        """
        Computes the profile from the output of the human-friendly algorithm.
        
            Parameters:
            Parameters:
                ranks (dict): a dictionary {[applicant]: {[job]: [ranking]}}
                matching (dict): a dictionary of {[applicant]: [job1, job2, ...]} of selected jobs.
                
            Returns:
                profile (np.ndarray): an m-vector where profile[i] is the number of applicants who were assigned their i'th pick of job
                
        """
        m = len(ranks[list(ranks.keys())[0]])
        profile = np.zeros(m, dtype=int)
        
        # re-order ranks to be increasing by 1, rather than arbitrary ranks
        for applicant in ranks:
            ranks[applicant] = {k: i for i, (k, v) in enumerate(sorted(ranks[applicant].items(), key=lambda item: item[1]))}
        
        for applicant in ranks:
            for job in ranks[applicant]:
                rank = ranks[applicant][job]
                if job in matching[applicant]:
                    profile[rank] += 1
        assert profile.sum() == m
        return profile

# %%
class RankMaximalAllocation:
    @classmethod
    def generate_matching(cls, ranks):
        """
        Returns a tuple (applicants, jobs) corresponding to a bipartite graph matching between applicants and jobs.
        
            Parameters:
                ranks (np.ndarray): an n x m matrix of rankings, where ranks[i,j] is the rank of applicant i for job j
        
            Returns:
                applicants: a vector of length min(n, m) of the selected applicants. A vector of indices.
                jobs: a vector of length min(n, m) of the selected jobs. A vector of indices.
                
                The computed matching is essentially [(applicants[0], jobs[0]), applicants[1], jobs[1], ...]
                The retured format is more efficient for indexing operations.
        
        """
        weights = cls.compute_weights(ranks)
        applicants, jobs = linear_sum_assignment(weights)
        return applicants, jobs
    
    @staticmethod
    def compute_weights(ranks):
        """
        Returns a weight matrix the same shape as ranks. Used with linear sum assignment.
        
            Parameters:
                ranks (np.ndarray): an n x m matrix of rankings, where ranks[i,j] is the rank of applicant i for job j

            Returns:
                weights (np.ndarray): an n x m matrix of weights. Selecting at most one element from each row/column of this matrix should result in a minimum sum.
        
        Cited from Greedy Matchings by Robert W. Irving
        https://citeseerx.ist.psu.edu/viewdoc/download;jsessionid=0D4318167ED18A3CE8DF2FB5B2EA8321?doi=10.1.1.119.1747&rep=rep1&type=pdf
        
        > However, a greedy matching can be found by transforming to an instance of the classical
        > maximum weight bipartite matching problem. This involves allo cating a suitably steeply 
        > decreasing sequence of weights to the positions in each applicant's preference list to 
        > ensure that, for any value of i, an applicant who improves from his (i+1)th to his ith 
        > choice would change the weight of applicants who move down from their (i+j)th choice, 
        > for any value of j >= 1. This can be achieved, for example, by assigning a weight of 
        > n^(m-i) to each applicant's ith choice.
        """
        (n, m) = ranks.shape
        
        # we use object to take advantage of numpy's broadcasting
        # and python's unlimited integer representation
        weights = np.array(n, dtype=object)**(np.array(m, dtype=object)-ranks.astype(object))
        
        # negative because the Hungarian algorithm is trying to
        # minimize the costs, and weights are higher for a higher rank
        return -weights

# %%
class RoundRobin:
    @staticmethod
    def generate_matching(ranks):
        (n, m) = ranks.shape

        available_jobs = list(range(m))

        maximum_available_assignments = min(n, m)

        assigned_jobs = np.empty(maximum_available_assignments ,dtype=int)

        lottery_order = np.random.choice(np.arange(n), maximum_available_assignments, replace=False)
        for i in range(maximum_available_assignments):
            applicant = lottery_order[i]

            jobs = np.arange(m)
            ranks_for_applicant = ranks[applicant]

            # recall that ranks[i] is the *rank* for items 0, 1, 2, etc
            # so if we want to get the actual jobs they want in order, we
            # need to argsort
            jobs_in_preferred_order = jobs[np.argsort(ranks_for_applicant)]

            for j in jobs_in_preferred_order:
                if j in available_jobs:
                    available_jobs.remove(j)
                    assigned_jobs[i] = j

                    break
        return lottery_order, assigned_jobs

# %% [markdown]
# ## TESTING

# %%
class Test:
    def generate_random_ranks(n, m):
        """
        Create a random n x m matrix of rankings.
        
            Parameters:
                n (int): number of applicants
                m (int): number of jobs
            
            Returns:
                ranks (np.ndarray): an n x m matrix of rankings, where ranks[i,j] is the rank of applicant i for job j
        """
        ranks = np.array([np.random.permutation(m) for a in range(n)])
        return ranks
    
    @classmethod
    def compare_algorithms(cls, n, m, num_iterations, rounds):
        """
        Return a score between -1 and 1, with -1 being Round Robin wins every time and 1 being RMA wins every time.
        
            Parameters:
                n (int): number of applicants
                m (int): number of jobs
                num_iterations (int): how many random rankings to generate 
                rounds (int): the number of random round robin rounds to make per random ranking. Total iterations = num_iterations * rounds
            
            Returns:
                score (int): score from each trial averaged over all runs. Value is -1 if Round Robin produces a more optimal output, 1 if RMA produces a more optimal output, and 0 if they produce the same output.
        """
        scores = []
    
        for i in range(num_iterations):
            ranks = cls.generate_random_ranks(n, m)

            applicants_rm, jobs_rm = RankMaximalAllocation.generate_matching(ranks)
            profile_rm = Profile.compute_profile(ranks, applicants_rm, jobs_rm)

            for j in range(rounds):
                applicants_rr, jobs_rr = RoundRobin.generate_matching(ranks)
                profile_rr = Profile.compute_profile(ranks, applicants_rr, jobs_rr)

                score = Profile.compare_profiles(profile_rm, profile_rr)
                scores.append(score)

                # Below should never happen due to optimality of assignment
                if score == -1:
                    print(f'Found exception ({n},{m}) {profile_rr} > {profile_rm}')
                    print(f'ranks\t{ranks.tolist()}')
                    print(f'jobs_rm\t{jobs_rm.tolist()}')
                    print(f'jobs_rr\t{jobs_rr.tolist()}')
                    return

        return np.mean(scores)
    
    @classmethod
    def generate_comparison_plot(cls, N, M, num_iterations=10, rounds=10):
        scores = np.zeros((N, M))
        # TODO: Determine the problem with N=1 or M=1?
        for n in np.arange(2, N):
            for m in np.arange(2, M):
                print(f'n: {n} \tm: {m}     \r', end='')
                score = cls.compare_algorithms(n, m, num_iterations, rounds)
                scores[n, m] = score
        heatmap = sns.heatmap(scores, vmin=-1, vmax=1, cmap='coolwarm')
        _ = heatmap.set(xlabel=r'$m$', ylabel=r'$n$')
        return heatmap

# %%
# Test.generate_comparison_plot(30, 30)

# %%
class MatchingGenerator:
    
    @staticmethod
    def generate_matching(rankings, strategy='RMA'):
        """
        
            Parameters:
                rankings (dict): a dictionary {[applicant]: {[job]: [ranking]}}
                strategy ('RMA' | 'RR'): the strategy. RMA for Rank-Maximal Allocation and RR for Round Robin
                
            Returns:
                matching (dict): a dictionary of {[applicant]: [job1, job2, ...]} of selected jobs.
        
        """
        
        # general strategy: convert rankings to a ranking matrix, using inverse indices to convert back
        # given n applicants and m jobs, both strategies return min(n, m) assignments.
        # therefore, if we want to allow applicants to receive multiple jobs, we basically give everyone
        # their top choice first, and then remove the selected items from the pool, and run the process again.
        # we combine all of the results. 
        # in total, each person should receive at minimum floor(m/n) jobs.
        
        applicants = list(rankings.keys())
        applicants_mapping = {applicant: i for i, applicant in enumerate(applicants)}
        applicants_inverse_mapping = {i: applicant for i, applicant in enumerate(applicants)}

        jobs = []
        for applicant in applicants:
            applicant_jobs = rankings[applicant].keys()
            for job in applicant_jobs:
                jobs.append(job)
        jobs = list(set(jobs)) # get unique
        
        total_jobs = len(jobs)
        
        
        matching = {applicant: [] for applicant in applicants}
        while len(jobs) > 0:

            jobs_mapping = {job: j for j, job in enumerate(jobs)}
            jobs_inverse_mapping = {j: job for j, job in enumerate(jobs)}

            n = len(applicants)
            m = len(jobs)

            # default everything to be ranked as low as possible
            ranks = 2 * m * np.ones((n, m))
            for i in range(n):
                for j in range(m):
                    applicant_name = applicants_inverse_mapping[i]
                    job_name = jobs_inverse_mapping[j]


                    if job_name in rankings[applicant_name]:
                        rank = rankings[applicant_name][job_name]
                        ranks[i, j] = rank

            generate_matching = RankMaximalAllocation.generate_matching if strategy == 'RMA' else RoundRobin.generate_matching
            matched_applicants, matched_jobs = generate_matching(ranks)

            for applicant, job in zip(matched_applicants, matched_jobs):
                applicant_name = applicants_inverse_mapping[applicant]
                job_name = jobs_inverse_mapping[job]
                matching[applicant_name].append(job_name)
                
            for job in matched_jobs:
                job_name = jobs_inverse_mapping[job]
                jobs.remove(job_name)

        
        total_jobs_matched = sum(map(lambda x: len(x), matching.values()))
        assert total_jobs_matched == total_jobs, f'Expected total_jobs_matched to equal {total_jobs} but found {total_jobs_matched}'
        
        return matching

# %%
rankings = {
    'alice': {'x':1, 'y':2, 'z':3, 'a':4, 'b':5, 'c': 6, 'd':7},
    'bob':   {'x':3, 'y': 1, 'z':2, 'a':4,'b':5, 'c': 6},
    'jane':   {'x':3, 'y': 2, 'z':1, 'a':4, 'b':5, 'c': 6},
}
MatchingGenerator.generate_matching(rankings)
# Out:
# {'alice': ['x', 'c'], 'bob': ['y', 'a', 'd'], 'jane': ['z', 'b']}

# %%
rankings = {
    'alice': {'x':1, 'y':2, 'z':3},
    'bob':   {'x':3, 'y': 1, 'z':2},
    'jane':   {'x':3, 'y': 2, 'z':1},
    'joe':    {'x':1, 'y': 3, 'z':2}
}
MatchingGenerator.generate_matching(rankings)
# Out:
# {'alice': ['x'], 'bob': ['y'], 'jane': ['z'], 'joe': []}

# %%
class PreferenceSheetParser:
    @staticmethod
    def generate_ranks(filename, ignore_sheet_names=['Inventory', 'Black Six', 'Info', 'Participants']):
        xlsx = pd.ExcelFile(filename)
        rankings = {}

        total_quantity = xlsx.parse()['Total Quantity'].sum()
        lowest_rank = total_quantity - 1

        for sheet_name in xlsx.sheet_names:
            if sheet_name in ignore_sheet_names:
                continue
                
            rankings[sheet_name] = {}

            df = pd.read_excel(xlsx, sheet_name)
            
            # Need to handle mistake in sheet where the 'Around the World' set appears twice
            df['Total Quantity'] = np.where(df['Set Name'] == 'Around the World', 2, df['Total Quantity'])
            df = df.drop_duplicates('Set Name')
            
            # Normalize rankings so that they begin at 0 instead of 1 
            df['Preference'] -= df['Preference'].min()


            for index, row in df.iterrows():
                rank, qty, name = row['Preference'], row['Total Quantity'], row['Set Name']
                
                

                rankings[sheet_name][name] = rank

                # all duplicates should get the lowest rank to avoid chance of duplication
                # but should also respect the original rank of the set (duplicates should not
                # all be considered equal)
                # for each quantity of duplication, we reduce the rank by the number of items 
                # to avoid getting duplicates of the same set, but add the rank to maintain
                # the original relative order
                if qty > 1:
                    for duplicate in range(1, qty):
                        rankings[sheet_name][f'{name}_duplicate_{duplicate}'] = duplicate*lowest_rank + rank
            
#             # the method of reducing duplication probability above results in ranks that are much lower than 
#             # the total quantity of items. We can thus re-normalize ranks to be between 0 and total_quantity-1
#             rankings[sheet_name] = {k: i for i, (k, v) in enumerate(sorted(rankings[sheet_name].items(), key=lambda item: item[1]))}

        assert all(map(lambda e: len(e) == total_quantity, rankings.values()))
        return rankings

# %%
ranks = PreferenceSheetParser.generate_ranks('Sept 10 Copy of 2022 Set Draft.xlsx')
ranks
# Out:
# {'Primus': {'Fire Dragon Attack': 0,
#   'Hogwarts™ Moment: Potions Class': 1,
#   'Dark Trooper Attack': 2,
#   'Snowtrooper Battle Pack': 3,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 4,
#   'Monster Jam El Toro Loco': 5,
#   'Monster Jam Megalodon': 6,
#   'Party Llama BeatBox': 7,
#   'Alien DJ BeatBox': 8,
#   'Punk Pirate BeatBox': 9,
#   'Candy Mermaid BeatBox': 10,
#   'Stunt Show Arena': 11,
#   'Motorcycle': 12,
#   'Motorcycle_duplicate_1': 177,
#   'Motorcycle_duplicate_2': 342,
#   'Motorcycle_duplicate_3': 507,
#   'Motorcycle_duplicate_4': 672,
#   'Motorcycle_duplicate_5': 837,
#   'Motorcycle_duplicate_6': 1002,
#   'Motorcycle_duplicate_7': 1167,
#   'Telehandler': 13,
#   'Telehandler_duplicate_1': 178,
#   'Telehandler_duplicate_2': 343,
#   'Telehandler_duplicate_3': 508,
#   'Telehandler_duplicate_4': 673,
#   'Telehandler_duplicate_5': 838,
#   'Telehandler_duplicate_6': 1003,
#   'Telehandler_duplicate_7': 1168,
#   'Lots of DOTS': 14,
#   'Lots of DOTS_duplicate_1': 179,
#   'Creative Party Kit': 15,
#   'Creative Party Kit_duplicate_1': 180,
#   'Cute Banana Pen Holder': 16,
#   'Message Board': 17,
#   'Skid Steer Loader': 18,
#   'Skid Steer Loader_duplicate_1': 183,
#   'Skid Steer Loader_duplicate_2': 348,
#   'Skid Steer Loader_duplicate_3': 513,
#   'Skid Steer Loader_duplicate_4': 678,
#   'Skid Steer Loader_duplicate_5': 843,
#   'Skid Steer Loader_duplicate_6': 1008,
#   'Skid Steer Loader_duplicate_7': 1173,
#   'Skid Steer Loader_duplicate_8': 1338,
#   'Skid Steer Loader_duplicate_9': 1503,
#   'Tree-Planting Vehicle': 19,
#   'Pet Playground': 20,
#   'Turtle Protection Vehicle': 21,
#   'Turtle Protection Vehicle_duplicate_1': 186,
#   'Turtle Protection Vehicle_duplicate_2': 351,
#   'Turtle Protection Vehicle_duplicate_3': 516,
#   'Pet Clinic': 22,
#   'Pet Clinic Ambulance': 23,
#   'Pet Clinic Ambulance_duplicate_1': 188,
#   'Pet Clinic Ambulance_duplicate_2': 353,
#   'Pet Clinic Ambulance_duplicate_3': 518,
#   'Magical Caravan': 24,
#   'Heartlake City School': 25,
#   'Forest House': 26,
#   "Elsa's Wagon Adventure": 27,
#   'Dolphin and Turtle': 28,
#   'Dolphin and Turtle_duplicate_1': 193,
#   'Dolphin and Turtle_duplicate_2': 358,
#   'Dolphin and Turtle_duplicate_3': 523,
#   'Street Racer': 29,
#   'Supersonic-jet': 30,
#   'Fantasy Forest Creatures': 31,
#   'Off-road Buggy': 32,
#   'Medieval Castle': 33,
#   'Safari Wildlife Tree House': 34,
#   'Caravan Family Holiday': 35,
#   'Creative Ocean Fun': 36,
#   'Bricks and Functions': 37,
#   'Creative Monsters': 38,
#   'Creative Monsters_duplicate_1': 203,
#   'Creative Monsters_duplicate_2': 368,
#   'Creative Monsters_duplicate_3': 533,
#   'Creative Building Bricks': 39,
#   'Around the World': 40,
#   'Around the World_duplicate_1': 205,
#   'Bricks and Wheels': 42,
#   'Creative Transparent Bricks': 43,
#   'Creative Building Time': 44,
#   'Bath Time Fun: Floating Animal Island': 45,
#   'Elf Club House': 46,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 47,
#   "Elsa and the Nokk's Ice Stable": 48,
#   'Fire Command Unit': 49,
#   'Holiday Camper Van': 50,
#   'Selfie Stunt Bike': 51,
#   'Selfie Stunt Bike_duplicate_1': 216,
#   'Selfie Stunt Bike_duplicate_2': 381,
#   'Selfie Stunt Bike_duplicate_3': 546,
#   'Selfie Stunt Bike_duplicate_4': 711,
#   'Selfie Stunt Bike_duplicate_5': 876,
#   'Selfie Stunt Bike_duplicate_6': 1041,
#   'Selfie Stunt Bike_duplicate_7': 1206,
#   'Selfie Stunt Bike_duplicate_8': 1371,
#   'Selfie Stunt Bike_duplicate_9': 1536,
#   'Chicken Stunt Bike': 52,
#   'Chicken Stunt Bike_duplicate_1': 217,
#   'Chicken Stunt Bike_duplicate_2': 382,
#   'Chicken Stunt Bike_duplicate_3': 547,
#   'Chicken Stunt Bike_duplicate_4': 712,
#   'Chicken Stunt Bike_duplicate_5': 877,
#   'Chicken Stunt Bike_duplicate_6': 1042,
#   'Chicken Stunt Bike_duplicate_7': 1207,
#   'Chicken Stunt Bike_duplicate_8': 1372,
#   'Chicken Stunt Bike_duplicate_9': 1537,
#   'Fire Stunt Bike': 53,
#   'Fire Stunt Bike_duplicate_1': 218,
#   'Fire Stunt Bike_duplicate_2': 383,
#   'Fire Stunt Bike_duplicate_3': 548,
#   'Fire Stunt Bike_duplicate_4': 713,
#   'Fire Stunt Bike_duplicate_5': 878,
#   'Fire Stunt Bike_duplicate_6': 1043,
#   'Fire Stunt Bike_duplicate_7': 1208,
#   'Fire Stunt Bike_duplicate_8': 1373,
#   'Fire Stunt Bike_duplicate_9': 1538,
#   'Ice Cream Truck Police Chase': 54,
#   'Fire Helicopter': 55,
#   'Fire Helicopter_duplicate_1': 220,
#   'Fire Helicopter_duplicate_2': 385,
#   'Fire Helicopter_duplicate_3': 550,
#   'Fire Helicopter_duplicate_4': 715,
#   'Fire Helicopter_duplicate_5': 880,
#   'Fire Helicopter_duplicate_6': 1045,
#   'Fire Helicopter_duplicate_7': 1210,
#   'Fire Rescue & Police Chase': 56,
#   'Race Car': 57,
#   'Race Car_duplicate_1': 222,
#   'Race Car_duplicate_2': 387,
#   'Race Car_duplicate_3': 552,
#   'Race Car_duplicate_4': 717,
#   'Race Car_duplicate_5': 882,
#   'Race Car_duplicate_6': 1047,
#   'Race Car_duplicate_7': 1212,
#   'Stunt Plane': 58,
#   'Stunt Plane_duplicate_1': 223,
#   'Stunt Plane_duplicate_2': 388,
#   'Stunt Plane_duplicate_3': 553,
#   'Stunt Plane_duplicate_4': 718,
#   'Stunt Plane_duplicate_5': 883,
#   'Stunt Plane_duplicate_6': 1048,
#   'Stunt Plane_duplicate_7': 1213,
#   'Cement Mixer Truck': 59,
#   'Picnic in the park': 60,
#   'Horse Transporter': 61,
#   'Beach Lifeguard Station': 62,
#   "Lloyd's Spinjitzu Ninja Training": 63,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 228,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 393,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 558,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 723,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 888,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1053,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1218,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1383,
#   "Jay's Spinjitzu Ninja Training": 64,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 229,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 394,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 559,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 724,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 889,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1054,
#   'Resistance X-Wing™': 65,
#   'Hogwarts™ Moment: Transfiguration Class': 66},
#  'Voxumo': {'Medieval Castle': 0,
#   'Caravan Family Holiday': 1,
#   'Safari Wildlife Tree House': 2,
#   'Fantasy Forest Creatures': 3,
#   'Dolphin and Turtle': 4,
#   'Dolphin and Turtle_duplicate_1': 169,
#   'Dolphin and Turtle_duplicate_2': 334,
#   'Dolphin and Turtle_duplicate_3': 499,
#   'Street Racer': 5,
#   'Supersonic-jet': 6,
#   'Off-road Buggy': 7,
#   'Holiday Camper Van': 8,
#   'Monster Jam Megalodon': 9,
#   'Monster Jam El Toro Loco': 10,
#   'Cute Banana Pen Holder': 11,
#   'Message Board': 13,
#   "Lloyd's Spinjitzu Ninja Training": 12,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 177,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 342,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 507,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 672,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 837,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1002,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1167,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1332,
#   "Jay's Spinjitzu Ninja Training": 14,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 179,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 344,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 509,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 674,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 839,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1004,
#   'Fire Dragon Attack': 15,
#   'Dark Trooper Attack': 16,
#   'Hogwarts™ Moment: Transfiguration Class': 17,
#   'Snowtrooper Battle Pack': 18,
#   'Resistance X-Wing™': 19,
#   'Elf Club House': 20,
#   'Creative Party Kit': 21,
#   'Creative Party Kit_duplicate_1': 186,
#   'Lots of DOTS': 22,
#   'Lots of DOTS_duplicate_1': 187,
#   'Skid Steer Loader': 23,
#   'Skid Steer Loader_duplicate_1': 188,
#   'Skid Steer Loader_duplicate_2': 353,
#   'Skid Steer Loader_duplicate_3': 518,
#   'Skid Steer Loader_duplicate_4': 683,
#   'Skid Steer Loader_duplicate_5': 848,
#   'Skid Steer Loader_duplicate_6': 1013,
#   'Skid Steer Loader_duplicate_7': 1178,
#   'Skid Steer Loader_duplicate_8': 1343,
#   'Skid Steer Loader_duplicate_9': 1508,
#   'Motorcycle': 24,
#   'Motorcycle_duplicate_1': 189,
#   'Motorcycle_duplicate_2': 354,
#   'Motorcycle_duplicate_3': 519,
#   'Motorcycle_duplicate_4': 684,
#   'Motorcycle_duplicate_5': 849,
#   'Motorcycle_duplicate_6': 1014,
#   'Motorcycle_duplicate_7': 1179,
#   'Telehandler': 25,
#   'Telehandler_duplicate_1': 190,
#   'Telehandler_duplicate_2': 355,
#   'Telehandler_duplicate_3': 520,
#   'Telehandler_duplicate_4': 685,
#   'Telehandler_duplicate_5': 850,
#   'Telehandler_duplicate_6': 1015,
#   'Telehandler_duplicate_7': 1180,
#   'Candy Mermaid BeatBox': 26,
#   'Punk Pirate BeatBox': 27,
#   'Alien DJ BeatBox': 28,
#   'Party Llama BeatBox': 29,
#   'Chicken Stunt Bike': 30,
#   'Chicken Stunt Bike_duplicate_1': 195,
#   'Chicken Stunt Bike_duplicate_2': 360,
#   'Chicken Stunt Bike_duplicate_3': 525,
#   'Chicken Stunt Bike_duplicate_4': 690,
#   'Chicken Stunt Bike_duplicate_5': 855,
#   'Chicken Stunt Bike_duplicate_6': 1020,
#   'Chicken Stunt Bike_duplicate_7': 1185,
#   'Chicken Stunt Bike_duplicate_8': 1350,
#   'Chicken Stunt Bike_duplicate_9': 1515,
#   'Ice Cream Truck Police Chase': 31,
#   'Cement Mixer Truck': 32,
#   'Picnic in the park': 33,
#   'Horse Transporter': 34,
#   'Beach Lifeguard Station': 35,
#   'Stunt Plane': 36,
#   'Stunt Plane_duplicate_1': 201,
#   'Stunt Plane_duplicate_2': 366,
#   'Stunt Plane_duplicate_3': 531,
#   'Stunt Plane_duplicate_4': 696,
#   'Stunt Plane_duplicate_5': 861,
#   'Stunt Plane_duplicate_6': 1026,
#   'Stunt Plane_duplicate_7': 1191,
#   'Race Car': 37,
#   'Race Car_duplicate_1': 202,
#   'Race Car_duplicate_2': 367,
#   'Race Car_duplicate_3': 532,
#   'Race Car_duplicate_4': 697,
#   'Race Car_duplicate_5': 862,
#   'Race Car_duplicate_6': 1027,
#   'Race Car_duplicate_7': 1192,
#   'Fire Rescue & Police Chase': 38,
#   'Fire Helicopter': 39,
#   'Fire Helicopter_duplicate_1': 204,
#   'Fire Helicopter_duplicate_2': 369,
#   'Fire Helicopter_duplicate_3': 534,
#   'Fire Helicopter_duplicate_4': 699,
#   'Fire Helicopter_duplicate_5': 864,
#   'Fire Helicopter_duplicate_6': 1029,
#   'Fire Helicopter_duplicate_7': 1194,
#   'Fire Stunt Bike': 40,
#   'Fire Stunt Bike_duplicate_1': 205,
#   'Fire Stunt Bike_duplicate_2': 370,
#   'Fire Stunt Bike_duplicate_3': 535,
#   'Fire Stunt Bike_duplicate_4': 700,
#   'Fire Stunt Bike_duplicate_5': 865,
#   'Fire Stunt Bike_duplicate_6': 1030,
#   'Fire Stunt Bike_duplicate_7': 1195,
#   'Fire Stunt Bike_duplicate_8': 1360,
#   'Fire Stunt Bike_duplicate_9': 1525,
#   'Selfie Stunt Bike': 41,
#   'Selfie Stunt Bike_duplicate_1': 206,
#   'Selfie Stunt Bike_duplicate_2': 371,
#   'Selfie Stunt Bike_duplicate_3': 536,
#   'Selfie Stunt Bike_duplicate_4': 701,
#   'Selfie Stunt Bike_duplicate_5': 866,
#   'Selfie Stunt Bike_duplicate_6': 1031,
#   'Selfie Stunt Bike_duplicate_7': 1196,
#   'Selfie Stunt Bike_duplicate_8': 1361,
#   'Selfie Stunt Bike_duplicate_9': 1526,
#   'Stunt Show Arena': 42,
#   'Fire Command Unit': 43,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 44,
#   'Hogwarts™ Moment: Potions Class': 45,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 46,
#   "Elsa and the Nokk's Ice Stable": 47,
#   'Creative Transparent Bricks': 48,
#   'Bricks and Wheels': 49,
#   'Around the World': 50,
#   'Around the World_duplicate_1': 215,
#   'Creative Building Bricks': 52,
#   'Creative Monsters': 53,
#   'Creative Monsters_duplicate_1': 218,
#   'Creative Monsters_duplicate_2': 383,
#   'Creative Monsters_duplicate_3': 548,
#   'Creative Ocean Fun': 54,
#   'Bricks and Functions': 55,
#   'Tree-Planting Vehicle': 56,
#   'Pet Playground': 57,
#   'Turtle Protection Vehicle': 58,
#   'Turtle Protection Vehicle_duplicate_1': 223,
#   'Turtle Protection Vehicle_duplicate_2': 388,
#   'Turtle Protection Vehicle_duplicate_3': 553,
#   'Pet Clinic': 59,
#   'Pet Clinic Ambulance': 60,
#   'Pet Clinic Ambulance_duplicate_1': 225,
#   'Pet Clinic Ambulance_duplicate_2': 390,
#   'Pet Clinic Ambulance_duplicate_3': 555,
#   'Magical Caravan': 61,
#   'Heartlake City School': 62,
#   'Forest House': 63,
#   "Elsa's Wagon Adventure": 64,
#   'Bath Time Fun: Floating Animal Island': 65,
#   'Creative Building Time': 66},
#  'MSEP': {'Medieval Castle': 0,
#   'Dolphin and Turtle': 1,
#   'Dolphin and Turtle_duplicate_1': 166,
#   'Dolphin and Turtle_duplicate_2': 331,
#   'Dolphin and Turtle_duplicate_3': 496,
#   'Fire Dragon Attack': 2,
#   'Elf Club House': 3,
#   'Creative Party Kit': 4,
#   'Creative Party Kit_duplicate_1': 169,
#   'Monster Jam Megalodon': 5,
#   'Stunt Show Arena': 6,
#   'Ice Cream Truck Police Chase': 7,
#   'Fire Rescue & Police Chase': 8,
#   'Horse Transporter': 9,
#   'Fire Command Unit': 10,
#   'Monster Jam El Toro Loco': 11,
#   'Lots of DOTS': 12,
#   'Lots of DOTS_duplicate_1': 177,
#   'Caravan Family Holiday': 13,
#   'Safari Wildlife Tree House': 14,
#   'Holiday Camper Van': 15,
#   'Street Racer': 16,
#   'Supersonic-jet': 17,
#   'Magical Caravan': 18,
#   'Candy Mermaid BeatBox': 19,
#   'Punk Pirate BeatBox': 20,
#   'Party Llama BeatBox': 21,
#   'Alien DJ BeatBox': 22,
#   'Message Board': 23,
#   'Cute Banana Pen Holder': 24,
#   'Tree-Planting Vehicle': 25,
#   'Pet Playground': 26,
#   'Heartlake City School': 27,
#   'Pet Clinic': 28,
#   'Forest House': 29,
#   'Turtle Protection Vehicle': 30,
#   'Turtle Protection Vehicle_duplicate_1': 195,
#   'Turtle Protection Vehicle_duplicate_2': 360,
#   'Turtle Protection Vehicle_duplicate_3': 525,
#   "Elsa and the Nokk's Ice Stable": 31,
#   'Fantasy Forest Creatures': 32,
#   'Off-road Buggy': 33,
#   'Hogwarts™ Moment: Potions Class': 34,
#   'Hogwarts™ Moment: Transfiguration Class': 35,
#   'Cement Mixer Truck': 36,
#   'Picnic in the park': 37,
#   'Beach Lifeguard Station': 38,
#   'Bath Time Fun: Floating Animal Island': 39,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 40,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 41,
#   "Elsa's Wagon Adventure": 42,
#   'Pet Clinic Ambulance': 43,
#   'Pet Clinic Ambulance_duplicate_1': 208,
#   'Pet Clinic Ambulance_duplicate_2': 373,
#   'Pet Clinic Ambulance_duplicate_3': 538,
#   'Creative Building Time': 44,
#   'Creative Transparent Bricks': 45,
#   'Bricks and Wheels': 46,
#   'Around the World': 47,
#   'Around the World_duplicate_1': 212,
#   'Stunt Plane': 49,
#   'Stunt Plane_duplicate_1': 214,
#   'Stunt Plane_duplicate_2': 379,
#   'Stunt Plane_duplicate_3': 544,
#   'Stunt Plane_duplicate_4': 709,
#   'Stunt Plane_duplicate_5': 874,
#   'Stunt Plane_duplicate_6': 1039,
#   'Stunt Plane_duplicate_7': 1204,
#   'Race Car': 50,
#   'Race Car_duplicate_1': 215,
#   'Race Car_duplicate_2': 380,
#   'Race Car_duplicate_3': 545,
#   'Race Car_duplicate_4': 710,
#   'Race Car_duplicate_5': 875,
#   'Race Car_duplicate_6': 1040,
#   'Race Car_duplicate_7': 1205,
#   'Fire Helicopter': 51,
#   'Fire Helicopter_duplicate_1': 216,
#   'Fire Helicopter_duplicate_2': 381,
#   'Fire Helicopter_duplicate_3': 546,
#   'Fire Helicopter_duplicate_4': 711,
#   'Fire Helicopter_duplicate_5': 876,
#   'Fire Helicopter_duplicate_6': 1041,
#   'Fire Helicopter_duplicate_7': 1206,
#   'Selfie Stunt Bike': 52,
#   'Selfie Stunt Bike_duplicate_1': 217,
#   'Selfie Stunt Bike_duplicate_2': 382,
#   'Selfie Stunt Bike_duplicate_3': 547,
#   'Selfie Stunt Bike_duplicate_4': 712,
#   'Selfie Stunt Bike_duplicate_5': 877,
#   'Selfie Stunt Bike_duplicate_6': 1042,
#   'Selfie Stunt Bike_duplicate_7': 1207,
#   'Selfie Stunt Bike_duplicate_8': 1372,
#   'Selfie Stunt Bike_duplicate_9': 1537,
#   "Lloyd's Spinjitzu Ninja Training": 53,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 218,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 383,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 548,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 713,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 878,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1043,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1208,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1373,
#   'Chicken Stunt Bike': 54,
#   'Chicken Stunt Bike_duplicate_1': 219,
#   'Chicken Stunt Bike_duplicate_2': 384,
#   'Chicken Stunt Bike_duplicate_3': 549,
#   'Chicken Stunt Bike_duplicate_4': 714,
#   'Chicken Stunt Bike_duplicate_5': 879,
#   'Chicken Stunt Bike_duplicate_6': 1044,
#   'Chicken Stunt Bike_duplicate_7': 1209,
#   'Chicken Stunt Bike_duplicate_8': 1374,
#   'Chicken Stunt Bike_duplicate_9': 1539,
#   'Fire Stunt Bike': 55,
#   'Fire Stunt Bike_duplicate_1': 220,
#   'Fire Stunt Bike_duplicate_2': 385,
#   'Fire Stunt Bike_duplicate_3': 550,
#   'Fire Stunt Bike_duplicate_4': 715,
#   'Fire Stunt Bike_duplicate_5': 880,
#   'Fire Stunt Bike_duplicate_6': 1045,
#   'Fire Stunt Bike_duplicate_7': 1210,
#   'Fire Stunt Bike_duplicate_8': 1375,
#   'Fire Stunt Bike_duplicate_9': 1540,
#   'Motorcycle': 56,
#   'Motorcycle_duplicate_1': 221,
#   'Motorcycle_duplicate_2': 386,
#   'Motorcycle_duplicate_3': 551,
#   'Motorcycle_duplicate_4': 716,
#   'Motorcycle_duplicate_5': 881,
#   'Motorcycle_duplicate_6': 1046,
#   'Motorcycle_duplicate_7': 1211,
#   'Skid Steer Loader': 57,
#   'Skid Steer Loader_duplicate_1': 222,
#   'Skid Steer Loader_duplicate_2': 387,
#   'Skid Steer Loader_duplicate_3': 552,
#   'Skid Steer Loader_duplicate_4': 717,
#   'Skid Steer Loader_duplicate_5': 882,
#   'Skid Steer Loader_duplicate_6': 1047,
#   'Skid Steer Loader_duplicate_7': 1212,
#   'Skid Steer Loader_duplicate_8': 1377,
#   'Skid Steer Loader_duplicate_9': 1542,
#   'Telehandler': 58,
#   'Telehandler_duplicate_1': 223,
#   'Telehandler_duplicate_2': 388,
#   'Telehandler_duplicate_3': 553,
#   'Telehandler_duplicate_4': 718,
#   'Telehandler_duplicate_5': 883,
#   'Telehandler_duplicate_6': 1048,
#   'Telehandler_duplicate_7': 1213,
#   'Resistance X-Wing™': 59,
#   "Jay's Spinjitzu Ninja Training": 60,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 225,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 390,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 555,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 720,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 885,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1050,
#   'Bricks and Functions': 61,
#   'Creative Ocean Fun': 62,
#   'Creative Monsters': 63,
#   'Creative Monsters_duplicate_1': 228,
#   'Creative Monsters_duplicate_2': 393,
#   'Creative Monsters_duplicate_3': 558,
#   'Creative Building Bricks': 64,
#   'Dark Trooper Attack': 65,
#   'Snowtrooper Battle Pack': 66},
#  'FuzzE': {'Bath Time Fun: Floating Animal Island': 0,
#   'Creative Building Time': 1,
#   'Medieval Castle': 2,
#   'Safari Wildlife Tree House': 3,
#   'Elf Club House': 4,
#   'Creative Party Kit': 5,
#   'Creative Party Kit_duplicate_1': 170,
#   'Lots of DOTS': 6,
#   'Lots of DOTS_duplicate_1': 171,
#   'Cute Banana Pen Holder': 7,
#   'Message Board': 8,
#   'Monster Jam Megalodon': 9,
#   'Monster Jam El Toro Loco': 10,
#   'Candy Mermaid BeatBox': 11,
#   'Punk Pirate BeatBox': 12,
#   'Alien DJ BeatBox': 13,
#   'Party Llama BeatBox': 14,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 15,
#   'Creative Transparent Bricks': 16,
#   'Bricks and Wheels': 17,
#   'Around the World': 18,
#   'Around the World_duplicate_1': 183,
#   'Creative Building Bricks': 20,
#   'Creative Monsters': 21,
#   'Creative Monsters_duplicate_1': 186,
#   'Creative Monsters_duplicate_2': 351,
#   'Creative Monsters_duplicate_3': 516,
#   'Creative Ocean Fun': 22,
#   'Bricks and Functions': 23,
#   'Caravan Family Holiday': 24,
#   'Off-road Buggy': 25,
#   'Fantasy Forest Creatures': 26,
#   'Supersonic-jet': 27,
#   'Street Racer': 28,
#   'Dolphin and Turtle': 29,
#   'Dolphin and Turtle_duplicate_1': 194,
#   'Dolphin and Turtle_duplicate_2': 359,
#   'Dolphin and Turtle_duplicate_3': 524,
#   "Elsa's Wagon Adventure": 30,
#   'Forest House': 31,
#   'Heartlake City School': 32,
#   'Magical Caravan': 33,
#   'Pet Clinic Ambulance': 34,
#   'Pet Clinic Ambulance_duplicate_1': 199,
#   'Pet Clinic Ambulance_duplicate_2': 364,
#   'Pet Clinic Ambulance_duplicate_3': 529,
#   'Pet Clinic': 35,
#   'Turtle Protection Vehicle': 36,
#   'Turtle Protection Vehicle_duplicate_1': 201,
#   'Turtle Protection Vehicle_duplicate_2': 366,
#   'Turtle Protection Vehicle_duplicate_3': 531,
#   'Pet Playground': 37,
#   'Tree-Planting Vehicle': 38,
#   'Skid Steer Loader': 39,
#   'Skid Steer Loader_duplicate_1': 204,
#   'Skid Steer Loader_duplicate_2': 369,
#   'Skid Steer Loader_duplicate_3': 534,
#   'Skid Steer Loader_duplicate_4': 699,
#   'Skid Steer Loader_duplicate_5': 864,
#   'Skid Steer Loader_duplicate_6': 1029,
#   'Skid Steer Loader_duplicate_7': 1194,
#   'Skid Steer Loader_duplicate_8': 1359,
#   'Skid Steer Loader_duplicate_9': 1524,
#   'Motorcycle': 40,
#   'Motorcycle_duplicate_1': 205,
#   'Motorcycle_duplicate_2': 370,
#   'Motorcycle_duplicate_3': 535,
#   'Motorcycle_duplicate_4': 700,
#   'Motorcycle_duplicate_5': 865,
#   'Motorcycle_duplicate_6': 1030,
#   'Motorcycle_duplicate_7': 1195,
#   'Telehandler': 41,
#   'Telehandler_duplicate_1': 206,
#   'Telehandler_duplicate_2': 371,
#   'Telehandler_duplicate_3': 536,
#   'Telehandler_duplicate_4': 701,
#   'Telehandler_duplicate_5': 866,
#   'Telehandler_duplicate_6': 1031,
#   'Telehandler_duplicate_7': 1196,
#   "Elsa and the Nokk's Ice Stable": 42,
#   'Fire Command Unit': 43,
#   'Holiday Camper Van': 44,
#   'Stunt Show Arena': 45,
#   'Selfie Stunt Bike': 46,
#   'Selfie Stunt Bike_duplicate_1': 211,
#   'Selfie Stunt Bike_duplicate_2': 376,
#   'Selfie Stunt Bike_duplicate_3': 541,
#   'Selfie Stunt Bike_duplicate_4': 706,
#   'Selfie Stunt Bike_duplicate_5': 871,
#   'Selfie Stunt Bike_duplicate_6': 1036,
#   'Selfie Stunt Bike_duplicate_7': 1201,
#   'Selfie Stunt Bike_duplicate_8': 1366,
#   'Selfie Stunt Bike_duplicate_9': 1531,
#   'Chicken Stunt Bike': 47,
#   'Chicken Stunt Bike_duplicate_1': 212,
#   'Chicken Stunt Bike_duplicate_2': 377,
#   'Chicken Stunt Bike_duplicate_3': 542,
#   'Chicken Stunt Bike_duplicate_4': 707,
#   'Chicken Stunt Bike_duplicate_5': 872,
#   'Chicken Stunt Bike_duplicate_6': 1037,
#   'Chicken Stunt Bike_duplicate_7': 1202,
#   'Chicken Stunt Bike_duplicate_8': 1367,
#   'Chicken Stunt Bike_duplicate_9': 1532,
#   'Fire Stunt Bike': 48,
#   'Fire Stunt Bike_duplicate_1': 213,
#   'Fire Stunt Bike_duplicate_2': 378,
#   'Fire Stunt Bike_duplicate_3': 543,
#   'Fire Stunt Bike_duplicate_4': 708,
#   'Fire Stunt Bike_duplicate_5': 873,
#   'Fire Stunt Bike_duplicate_6': 1038,
#   'Fire Stunt Bike_duplicate_7': 1203,
#   'Fire Stunt Bike_duplicate_8': 1368,
#   'Fire Stunt Bike_duplicate_9': 1533,
#   'Ice Cream Truck Police Chase': 49,
#   'Fire Helicopter': 50,
#   'Fire Helicopter_duplicate_1': 215,
#   'Fire Helicopter_duplicate_2': 380,
#   'Fire Helicopter_duplicate_3': 545,
#   'Fire Helicopter_duplicate_4': 710,
#   'Fire Helicopter_duplicate_5': 875,
#   'Fire Helicopter_duplicate_6': 1040,
#   'Fire Helicopter_duplicate_7': 1205,
#   'Fire Rescue & Police Chase': 51,
#   'Race Car': 52,
#   'Race Car_duplicate_1': 217,
#   'Race Car_duplicate_2': 382,
#   'Race Car_duplicate_3': 547,
#   'Race Car_duplicate_4': 712,
#   'Race Car_duplicate_5': 877,
#   'Race Car_duplicate_6': 1042,
#   'Race Car_duplicate_7': 1207,
#   'Stunt Plane': 53,
#   'Stunt Plane_duplicate_1': 218,
#   'Stunt Plane_duplicate_2': 383,
#   'Stunt Plane_duplicate_3': 548,
#   'Stunt Plane_duplicate_4': 713,
#   'Stunt Plane_duplicate_5': 878,
#   'Stunt Plane_duplicate_6': 1043,
#   'Stunt Plane_duplicate_7': 1208,
#   'Cement Mixer Truck': 54,
#   'Picnic in the park': 55,
#   'Horse Transporter': 56,
#   'Beach Lifeguard Station': 57,
#   "Lloyd's Spinjitzu Ninja Training": 58,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 223,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 388,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 553,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 718,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 883,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1048,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1213,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1378,
#   "Jay's Spinjitzu Ninja Training": 59,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 224,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 389,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 554,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 719,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 884,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1049,
#   'Fire Dragon Attack': 60,
#   'Resistance X-Wing™': 61,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 62,
#   'Snowtrooper Battle Pack': 63,
#   'Dark Trooper Attack': 64,
#   'Hogwarts™ Moment: Transfiguration Class': 65,
#   'Hogwarts™ Moment: Potions Class': 66},
#  'dviddy': {'Medieval Castle': 0,
#   'Fire Dragon Attack': 1,
#   'Monster Jam Megalodon': 2,
#   'Monster Jam El Toro Loco': 3,
#   'Elf Club House': 4,
#   'Dolphin and Turtle': 5,
#   'Dolphin and Turtle_duplicate_1': 170,
#   'Dolphin and Turtle_duplicate_2': 335,
#   'Dolphin and Turtle_duplicate_3': 500,
#   'Fantasy Forest Creatures': 6,
#   'Heartlake City School': 7,
#   'Magical Caravan': 8,
#   'Lots of DOTS': 9,
#   'Lots of DOTS_duplicate_1': 174,
#   'Creative Party Kit': 10,
#   'Creative Party Kit_duplicate_1': 175,
#   'Message Board': 11,
#   'Cute Banana Pen Holder': 12,
#   'Stunt Show Arena': 13,
#   'Caravan Family Holiday': 14,
#   'Safari Wildlife Tree House': 15,
#   'Street Racer': 16,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 17,
#   'Dark Trooper Attack': 18,
#   'Hogwarts™ Moment: Transfiguration Class': 19,
#   'Hogwarts™ Moment: Potions Class': 20,
#   'Snowtrooper Battle Pack': 21,
#   'Beach Lifeguard Station': 22,
#   'Picnic in the park': 23,
#   'Horse Transporter': 24,
#   'Creative Transparent Bricks': 25,
#   'Bricks and Wheels': 26,
#   'Around the World': 27,
#   'Around the World_duplicate_1': 192,
#   'Creative Building Bricks': 29,
#   'Creative Monsters': 30,
#   'Creative Monsters_duplicate_1': 195,
#   'Creative Monsters_duplicate_2': 360,
#   'Creative Monsters_duplicate_3': 525,
#   'Creative Ocean Fun': 31,
#   'Bricks and Functions': 32,
#   'Off-road Buggy': 33,
#   'Supersonic-jet': 34,
#   "Elsa's Wagon Adventure": 35,
#   'Forest House': 36,
#   'Pet Clinic Ambulance': 37,
#   'Pet Clinic Ambulance_duplicate_1': 202,
#   'Pet Clinic Ambulance_duplicate_2': 367,
#   'Pet Clinic Ambulance_duplicate_3': 532,
#   'Pet Clinic': 38,
#   'Turtle Protection Vehicle': 39,
#   'Turtle Protection Vehicle_duplicate_1': 204,
#   'Turtle Protection Vehicle_duplicate_2': 369,
#   'Turtle Protection Vehicle_duplicate_3': 534,
#   'Pet Playground': 40,
#   'Tree-Planting Vehicle': 41,
#   'Skid Steer Loader': 42,
#   'Skid Steer Loader_duplicate_1': 207,
#   'Skid Steer Loader_duplicate_2': 372,
#   'Skid Steer Loader_duplicate_3': 537,
#   'Skid Steer Loader_duplicate_4': 702,
#   'Skid Steer Loader_duplicate_5': 867,
#   'Skid Steer Loader_duplicate_6': 1032,
#   'Skid Steer Loader_duplicate_7': 1197,
#   'Skid Steer Loader_duplicate_8': 1362,
#   'Skid Steer Loader_duplicate_9': 1527,
#   'Motorcycle': 43,
#   'Motorcycle_duplicate_1': 208,
#   'Motorcycle_duplicate_2': 373,
#   'Motorcycle_duplicate_3': 538,
#   'Motorcycle_duplicate_4': 703,
#   'Motorcycle_duplicate_5': 868,
#   'Motorcycle_duplicate_6': 1033,
#   'Motorcycle_duplicate_7': 1198,
#   'Telehandler': 44,
#   'Telehandler_duplicate_1': 209,
#   'Telehandler_duplicate_2': 374,
#   'Telehandler_duplicate_3': 539,
#   'Telehandler_duplicate_4': 704,
#   'Telehandler_duplicate_5': 869,
#   'Telehandler_duplicate_6': 1034,
#   'Telehandler_duplicate_7': 1199,
#   'Candy Mermaid BeatBox': 45,
#   'Punk Pirate BeatBox': 46,
#   'Alien DJ BeatBox': 47,
#   'Party Llama BeatBox': 48,
#   'Fire Command Unit': 49,
#   'Holiday Camper Van': 50,
#   'Race Car': 51,
#   'Race Car_duplicate_1': 216,
#   'Race Car_duplicate_2': 381,
#   'Race Car_duplicate_3': 546,
#   'Race Car_duplicate_4': 711,
#   'Race Car_duplicate_5': 876,
#   'Race Car_duplicate_6': 1041,
#   'Race Car_duplicate_7': 1206,
#   'Stunt Plane': 52,
#   'Stunt Plane_duplicate_1': 217,
#   'Stunt Plane_duplicate_2': 382,
#   'Stunt Plane_duplicate_3': 547,
#   'Stunt Plane_duplicate_4': 712,
#   'Stunt Plane_duplicate_5': 877,
#   'Stunt Plane_duplicate_6': 1042,
#   'Stunt Plane_duplicate_7': 1207,
#   'Cement Mixer Truck': 53,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 54,
#   "Elsa and the Nokk's Ice Stable": 55,
#   'Selfie Stunt Bike': 56,
#   'Selfie Stunt Bike_duplicate_1': 221,
#   'Selfie Stunt Bike_duplicate_2': 386,
#   'Selfie Stunt Bike_duplicate_3': 551,
#   'Selfie Stunt Bike_duplicate_4': 716,
#   'Selfie Stunt Bike_duplicate_5': 881,
#   'Selfie Stunt Bike_duplicate_6': 1046,
#   'Selfie Stunt Bike_duplicate_7': 1211,
#   'Selfie Stunt Bike_duplicate_8': 1376,
#   'Selfie Stunt Bike_duplicate_9': 1541,
#   'Chicken Stunt Bike': 57,
#   'Chicken Stunt Bike_duplicate_1': 222,
#   'Chicken Stunt Bike_duplicate_2': 387,
#   'Chicken Stunt Bike_duplicate_3': 552,
#   'Chicken Stunt Bike_duplicate_4': 717,
#   'Chicken Stunt Bike_duplicate_5': 882,
#   'Chicken Stunt Bike_duplicate_6': 1047,
#   'Chicken Stunt Bike_duplicate_7': 1212,
#   'Chicken Stunt Bike_duplicate_8': 1377,
#   'Chicken Stunt Bike_duplicate_9': 1542,
#   'Fire Stunt Bike': 58,
#   'Fire Stunt Bike_duplicate_1': 223,
#   'Fire Stunt Bike_duplicate_2': 388,
#   'Fire Stunt Bike_duplicate_3': 553,
#   'Fire Stunt Bike_duplicate_4': 718,
#   'Fire Stunt Bike_duplicate_5': 883,
#   'Fire Stunt Bike_duplicate_6': 1048,
#   'Fire Stunt Bike_duplicate_7': 1213,
#   'Fire Stunt Bike_duplicate_8': 1378,
#   'Fire Stunt Bike_duplicate_9': 1543,
#   'Ice Cream Truck Police Chase': 59,
#   'Fire Helicopter': 60,
#   'Fire Helicopter_duplicate_1': 225,
#   'Fire Helicopter_duplicate_2': 390,
#   'Fire Helicopter_duplicate_3': 555,
#   'Fire Helicopter_duplicate_4': 720,
#   'Fire Helicopter_duplicate_5': 885,
#   'Fire Helicopter_duplicate_6': 1050,
#   'Fire Helicopter_duplicate_7': 1215,
#   'Fire Rescue & Police Chase': 61,
#   "Lloyd's Spinjitzu Ninja Training": 62,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 227,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 392,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 557,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 722,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 887,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1052,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1217,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1382,
#   "Jay's Spinjitzu Ninja Training": 63,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 228,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 393,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 558,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 723,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 888,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1053,
#   'Resistance X-Wing™': 64,
#   'Creative Building Time': 65,
#   'Bath Time Fun: Floating Animal Island': 66},
#  'awesomenessborn': {'Medieval Castle': 0,
#   'Dark Trooper Attack': 1,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 2,
#   'Snowtrooper Battle Pack': 3,
#   'Alien DJ BeatBox': 4,
#   'Monster Jam Megalodon': 5,
#   'Dolphin and Turtle': 6,
#   'Dolphin and Turtle_duplicate_1': 171,
#   'Dolphin and Turtle_duplicate_2': 336,
#   'Dolphin and Turtle_duplicate_3': 501,
#   'Monster Jam El Toro Loco': 7,
#   'Hogwarts™ Moment: Potions Class': 8,
#   'Hogwarts™ Moment: Transfiguration Class': 9,
#   'Party Llama BeatBox': 10,
#   'Caravan Family Holiday': 11,
#   'Safari Wildlife Tree House': 12,
#   'Off-road Buggy': 13,
#   'Fantasy Forest Creatures': 14,
#   'Supersonic-jet': 15,
#   'Street Racer': 16,
#   'Elf Club House': 17,
#   'Bath Time Fun: Floating Animal Island': 18,
#   'Creative Building Time': 19,
#   'Creative Transparent Bricks': 20,
#   'Bricks and Wheels': 21,
#   'Around the World': 22,
#   'Around the World_duplicate_1': 187,
#   'Creative Building Bricks': 24,
#   'Creative Monsters': 25,
#   'Creative Monsters_duplicate_1': 190,
#   'Creative Monsters_duplicate_2': 355,
#   'Creative Monsters_duplicate_3': 520,
#   'Creative Ocean Fun': 26,
#   'Bricks and Functions': 27,
#   'Forest House': 28,
#   "Elsa's Wagon Adventure": 29,
#   'Heartlake City School': 30,
#   'Magical Caravan': 31,
#   'Pet Clinic Ambulance': 32,
#   'Pet Clinic Ambulance_duplicate_1': 197,
#   'Pet Clinic Ambulance_duplicate_2': 362,
#   'Pet Clinic Ambulance_duplicate_3': 527,
#   'Pet Clinic': 33,
#   'Turtle Protection Vehicle': 34,
#   'Turtle Protection Vehicle_duplicate_1': 199,
#   'Turtle Protection Vehicle_duplicate_2': 364,
#   'Turtle Protection Vehicle_duplicate_3': 529,
#   'Pet Playground': 35,
#   'Tree-Planting Vehicle': 36,
#   'Creative Party Kit': 37,
#   'Creative Party Kit_duplicate_1': 202,
#   'Lots of DOTS': 38,
#   'Lots of DOTS_duplicate_1': 203,
#   'Cute Banana Pen Holder': 39,
#   'Message Board': 40,
#   'Skid Steer Loader': 41,
#   'Skid Steer Loader_duplicate_1': 206,
#   'Skid Steer Loader_duplicate_2': 371,
#   'Skid Steer Loader_duplicate_3': 536,
#   'Skid Steer Loader_duplicate_4': 701,
#   'Skid Steer Loader_duplicate_5': 866,
#   'Skid Steer Loader_duplicate_6': 1031,
#   'Skid Steer Loader_duplicate_7': 1196,
#   'Skid Steer Loader_duplicate_8': 1361,
#   'Skid Steer Loader_duplicate_9': 1526,
#   'Motorcycle': 42,
#   'Motorcycle_duplicate_1': 207,
#   'Motorcycle_duplicate_2': 372,
#   'Motorcycle_duplicate_3': 537,
#   'Motorcycle_duplicate_4': 702,
#   'Motorcycle_duplicate_5': 867,
#   'Motorcycle_duplicate_6': 1032,
#   'Motorcycle_duplicate_7': 1197,
#   'Telehandler': 43,
#   'Telehandler_duplicate_1': 208,
#   'Telehandler_duplicate_2': 373,
#   'Telehandler_duplicate_3': 538,
#   'Telehandler_duplicate_4': 703,
#   'Telehandler_duplicate_5': 868,
#   'Telehandler_duplicate_6': 1033,
#   'Telehandler_duplicate_7': 1198,
#   'Candy Mermaid BeatBox': 44,
#   'Punk Pirate BeatBox': 45,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 46,
#   "Elsa and the Nokk's Ice Stable": 47,
#   'Fire Command Unit': 48,
#   'Holiday Camper Van': 49,
#   'Stunt Show Arena': 50,
#   'Selfie Stunt Bike': 51,
#   'Selfie Stunt Bike_duplicate_1': 216,
#   'Selfie Stunt Bike_duplicate_2': 381,
#   'Selfie Stunt Bike_duplicate_3': 546,
#   'Selfie Stunt Bike_duplicate_4': 711,
#   'Selfie Stunt Bike_duplicate_5': 876,
#   'Selfie Stunt Bike_duplicate_6': 1041,
#   'Selfie Stunt Bike_duplicate_7': 1206,
#   'Selfie Stunt Bike_duplicate_8': 1371,
#   'Selfie Stunt Bike_duplicate_9': 1536,
#   'Chicken Stunt Bike': 52,
#   'Chicken Stunt Bike_duplicate_1': 217,
#   'Chicken Stunt Bike_duplicate_2': 382,
#   'Chicken Stunt Bike_duplicate_3': 547,
#   'Chicken Stunt Bike_duplicate_4': 712,
#   'Chicken Stunt Bike_duplicate_5': 877,
#   'Chicken Stunt Bike_duplicate_6': 1042,
#   'Chicken Stunt Bike_duplicate_7': 1207,
#   'Chicken Stunt Bike_duplicate_8': 1372,
#   'Chicken Stunt Bike_duplicate_9': 1537,
#   'Fire Stunt Bike': 53,
#   'Fire Stunt Bike_duplicate_1': 218,
#   'Fire Stunt Bike_duplicate_2': 383,
#   'Fire Stunt Bike_duplicate_3': 548,
#   'Fire Stunt Bike_duplicate_4': 713,
#   'Fire Stunt Bike_duplicate_5': 878,
#   'Fire Stunt Bike_duplicate_6': 1043,
#   'Fire Stunt Bike_duplicate_7': 1208,
#   'Fire Stunt Bike_duplicate_8': 1373,
#   'Fire Stunt Bike_duplicate_9': 1538,
#   'Ice Cream Truck Police Chase': 54,
#   'Fire Helicopter': 55,
#   'Fire Helicopter_duplicate_1': 220,
#   'Fire Helicopter_duplicate_2': 385,
#   'Fire Helicopter_duplicate_3': 550,
#   'Fire Helicopter_duplicate_4': 715,
#   'Fire Helicopter_duplicate_5': 880,
#   'Fire Helicopter_duplicate_6': 1045,
#   'Fire Helicopter_duplicate_7': 1210,
#   'Fire Rescue & Police Chase': 56,
#   'Race Car': 57,
#   'Race Car_duplicate_1': 222,
#   'Race Car_duplicate_2': 387,
#   'Race Car_duplicate_3': 552,
#   'Race Car_duplicate_4': 717,
#   'Race Car_duplicate_5': 882,
#   'Race Car_duplicate_6': 1047,
#   'Race Car_duplicate_7': 1212,
#   'Stunt Plane': 58,
#   'Stunt Plane_duplicate_1': 223,
#   'Stunt Plane_duplicate_2': 388,
#   'Stunt Plane_duplicate_3': 553,
#   'Stunt Plane_duplicate_4': 718,
#   'Stunt Plane_duplicate_5': 883,
#   'Stunt Plane_duplicate_6': 1048,
#   'Stunt Plane_duplicate_7': 1213,
#   'Cement Mixer Truck': 59,
#   'Picnic in the park': 60,
#   'Horse Transporter': 61,
#   'Beach Lifeguard Station': 62,
#   "Lloyd's Spinjitzu Ninja Training": 63,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 228,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 393,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 558,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 723,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 888,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1053,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1218,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1383,
#   "Jay's Spinjitzu Ninja Training": 64,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 229,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 394,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 559,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 724,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 889,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1054,
#   'Fire Dragon Attack': 65,
#   'Resistance X-Wing™': 66},
#  'woomyworld': {'Fire Dragon Attack': 0,
#   'Elf Club House': 1,
#   'Stunt Show Arena': 2,
#   'Bath Time Fun: Floating Animal Island': 3,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 4,
#   'Medieval Castle': 5,
#   'Monster Jam Megalodon': 6,
#   'Monster Jam El Toro Loco': 7,
#   'Supersonic-jet': 8,
#   'Caravan Family Holiday': 9,
#   'Safari Wildlife Tree House': 10,
#   'Magical Caravan': 11,
#   'Tree-Planting Vehicle': 12,
#   'Fantasy Forest Creatures': 13,
#   'Off-road Buggy': 14,
#   'Hogwarts™ Moment: Potions Class': 15,
#   'Hogwarts™ Moment: Transfiguration Class': 16,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 17,
#   'Snowtrooper Battle Pack': 18,
#   'Dark Trooper Attack': 19,
#   "Elsa and the Nokk's Ice Stable": 20,
#   'Street Racer': 21,
#   'Heartlake City School': 22,
#   'Forest House': 23,
#   'Skid Steer Loader': 24,
#   'Skid Steer Loader_duplicate_1': 189,
#   'Skid Steer Loader_duplicate_2': 354,
#   'Skid Steer Loader_duplicate_3': 519,
#   'Skid Steer Loader_duplicate_4': 684,
#   'Skid Steer Loader_duplicate_5': 849,
#   'Skid Steer Loader_duplicate_6': 1014,
#   'Skid Steer Loader_duplicate_7': 1179,
#   'Skid Steer Loader_duplicate_8': 1344,
#   'Skid Steer Loader_duplicate_9': 1509,
#   'Motorcycle': 25,
#   'Motorcycle_duplicate_1': 190,
#   'Motorcycle_duplicate_2': 355,
#   'Motorcycle_duplicate_3': 520,
#   'Motorcycle_duplicate_4': 685,
#   'Motorcycle_duplicate_5': 850,
#   'Motorcycle_duplicate_6': 1015,
#   'Motorcycle_duplicate_7': 1180,
#   'Pet Playground': 26,
#   'Resistance X-Wing™': 27,
#   'Dolphin and Turtle': 28,
#   'Dolphin and Turtle_duplicate_1': 193,
#   'Dolphin and Turtle_duplicate_2': 358,
#   'Dolphin and Turtle_duplicate_3': 523,
#   'Message Board': 29,
#   'Creative Transparent Bricks': 30,
#   'Lots of DOTS': 31,
#   'Lots of DOTS_duplicate_1': 196,
#   'Creative Party Kit': 32,
#   'Creative Party Kit_duplicate_1': 197,
#   'Beach Lifeguard Station': 33,
#   'Horse Transporter': 34,
#   'Picnic in the park': 35,
#   'Cement Mixer Truck': 36,
#   'Fire Rescue & Police Chase': 37,
#   'Ice Cream Truck Police Chase': 38,
#   'Holiday Camper Van': 39,
#   'Fire Command Unit': 40,
#   "Elsa's Wagon Adventure": 41,
#   'Turtle Protection Vehicle': 42,
#   'Turtle Protection Vehicle_duplicate_1': 207,
#   'Turtle Protection Vehicle_duplicate_2': 372,
#   'Turtle Protection Vehicle_duplicate_3': 537,
#   'Pet Clinic Ambulance': 43,
#   'Pet Clinic Ambulance_duplicate_1': 208,
#   'Pet Clinic Ambulance_duplicate_2': 373,
#   'Pet Clinic Ambulance_duplicate_3': 538,
#   'Pet Clinic': 44,
#   'Fire Helicopter': 45,
#   'Fire Helicopter_duplicate_1': 210,
#   'Fire Helicopter_duplicate_2': 375,
#   'Fire Helicopter_duplicate_3': 540,
#   'Fire Helicopter_duplicate_4': 705,
#   'Fire Helicopter_duplicate_5': 870,
#   'Fire Helicopter_duplicate_6': 1035,
#   'Fire Helicopter_duplicate_7': 1200,
#   'Telehandler': 46,
#   'Telehandler_duplicate_1': 211,
#   'Telehandler_duplicate_2': 376,
#   'Telehandler_duplicate_3': 541,
#   'Telehandler_duplicate_4': 706,
#   'Telehandler_duplicate_5': 871,
#   'Telehandler_duplicate_6': 1036,
#   'Telehandler_duplicate_7': 1201,
#   "Jay's Spinjitzu Ninja Training": 47,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 212,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 377,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 542,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 707,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 872,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1037,
#   "Lloyd's Spinjitzu Ninja Training": 48,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 213,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 378,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 543,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 708,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 873,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1038,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1203,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1368,
#   'Fire Stunt Bike': 49,
#   'Fire Stunt Bike_duplicate_1': 214,
#   'Fire Stunt Bike_duplicate_2': 379,
#   'Fire Stunt Bike_duplicate_3': 544,
#   'Fire Stunt Bike_duplicate_4': 709,
#   'Fire Stunt Bike_duplicate_5': 874,
#   'Fire Stunt Bike_duplicate_6': 1039,
#   'Fire Stunt Bike_duplicate_7': 1204,
#   'Fire Stunt Bike_duplicate_8': 1369,
#   'Fire Stunt Bike_duplicate_9': 1534,
#   'Selfie Stunt Bike': 50,
#   'Selfie Stunt Bike_duplicate_1': 215,
#   'Selfie Stunt Bike_duplicate_2': 380,
#   'Selfie Stunt Bike_duplicate_3': 545,
#   'Selfie Stunt Bike_duplicate_4': 710,
#   'Selfie Stunt Bike_duplicate_5': 875,
#   'Selfie Stunt Bike_duplicate_6': 1040,
#   'Selfie Stunt Bike_duplicate_7': 1205,
#   'Selfie Stunt Bike_duplicate_8': 1370,
#   'Selfie Stunt Bike_duplicate_9': 1535,
#   'Chicken Stunt Bike': 51,
#   'Chicken Stunt Bike_duplicate_1': 216,
#   'Chicken Stunt Bike_duplicate_2': 381,
#   'Chicken Stunt Bike_duplicate_3': 546,
#   'Chicken Stunt Bike_duplicate_4': 711,
#   'Chicken Stunt Bike_duplicate_5': 876,
#   'Chicken Stunt Bike_duplicate_6': 1041,
#   'Chicken Stunt Bike_duplicate_7': 1206,
#   'Chicken Stunt Bike_duplicate_8': 1371,
#   'Chicken Stunt Bike_duplicate_9': 1536,
#   'Race Car': 52,
#   'Race Car_duplicate_1': 217,
#   'Race Car_duplicate_2': 382,
#   'Race Car_duplicate_3': 547,
#   'Race Car_duplicate_4': 712,
#   'Race Car_duplicate_5': 877,
#   'Race Car_duplicate_6': 1042,
#   'Race Car_duplicate_7': 1207,
#   'Stunt Plane': 53,
#   'Stunt Plane_duplicate_1': 218,
#   'Stunt Plane_duplicate_2': 383,
#   'Stunt Plane_duplicate_3': 548,
#   'Stunt Plane_duplicate_4': 713,
#   'Stunt Plane_duplicate_5': 878,
#   'Stunt Plane_duplicate_6': 1043,
#   'Stunt Plane_duplicate_7': 1208,
#   'Cute Banana Pen Holder': 54,
#   'Creative Ocean Fun': 55,
#   'Creative Monsters': 56,
#   'Creative Monsters_duplicate_1': 221,
#   'Creative Monsters_duplicate_2': 386,
#   'Creative Monsters_duplicate_3': 551,
#   'Bricks and Functions': 57,
#   'Bricks and Wheels': 58,
#   'Around the World': 59,
#   'Around the World_duplicate_1': 224,
#   'Creative Building Bricks': 61,
#   'Creative Building Time': 62,
#   'Candy Mermaid BeatBox': 63,
#   'Punk Pirate BeatBox': 64,
#   'Alien DJ BeatBox': 65,
#   'Party Llama BeatBox': 66},
#  'ChocolateFrogs': {'Medieval Castle': 0,
#   'Fire Dragon Attack': 1,
#   'Dark Trooper Attack': 2,
#   'Ice Cream Truck Police Chase': 3,
#   'Alien DJ BeatBox': 4,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 5,
#   'Bricks and Functions': 6,
#   'Hogwarts™ Moment: Potions Class': 7,
#   'Lots of DOTS': 8,
#   'Lots of DOTS_duplicate_1': 173,
#   'Supersonic-jet': 9,
#   'Caravan Family Holiday': 10,
#   "Lloyd's Spinjitzu Ninja Training": 11,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 176,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 341,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 506,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 671,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 836,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1001,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1166,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1331,
#   'Safari Wildlife Tree House': 12,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 13,
#   'Snowtrooper Battle Pack': 14,
#   'Creative Building Bricks': 15,
#   'Around the World': 16,
#   'Around the World_duplicate_1': 181,
#   'Bricks and Wheels': 17,
#   'Creative Transparent Bricks': 18,
#   'Creative Ocean Fun': 19,
#   'Holiday Camper Van': 21,
#   'Turtle Protection Vehicle': 22,
#   'Turtle Protection Vehicle_duplicate_1': 187,
#   'Turtle Protection Vehicle_duplicate_2': 352,
#   'Turtle Protection Vehicle_duplicate_3': 517,
#   'Creative Monsters': 23,
#   'Creative Monsters_duplicate_1': 188,
#   'Creative Monsters_duplicate_2': 353,
#   'Creative Monsters_duplicate_3': 518,
#   'Off-road Buggy': 24,
#   'Magical Caravan': 25,
#   'Stunt Show Arena': 26,
#   'Monster Jam El Toro Loco': 27,
#   "Jay's Spinjitzu Ninja Training": 28,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 193,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 358,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 523,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 688,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 853,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1018,
#   'Fantasy Forest Creatures': 29,
#   'Tree-Planting Vehicle': 31,
#   'Heartlake City School': 30,
#   'Street Racer': 32,
#   'Motorcycle': 33,
#   'Motorcycle_duplicate_1': 198,
#   'Motorcycle_duplicate_2': 363,
#   'Motorcycle_duplicate_3': 528,
#   'Motorcycle_duplicate_4': 693,
#   'Motorcycle_duplicate_5': 858,
#   'Motorcycle_duplicate_6': 1023,
#   'Motorcycle_duplicate_7': 1188,
#   'Creative Party Kit': 34,
#   'Creative Party Kit_duplicate_1': 199,
#   'Resistance X-Wing™': 35,
#   'Cute Banana Pen Holder': 36,
#   'Dolphin and Turtle': 37,
#   'Dolphin and Turtle_duplicate_1': 202,
#   'Dolphin and Turtle_duplicate_2': 367,
#   'Dolphin and Turtle_duplicate_3': 532,
#   'Race Car': 38,
#   'Race Car_duplicate_1': 203,
#   'Race Car_duplicate_2': 368,
#   'Race Car_duplicate_3': 533,
#   'Race Car_duplicate_4': 698,
#   'Race Car_duplicate_5': 863,
#   'Race Car_duplicate_6': 1028,
#   'Race Car_duplicate_7': 1193,
#   'Pet Playground': 39,
#   'Message Board': 40,
#   'Hogwarts™ Moment: Transfiguration Class': 41,
#   'Forest House': 42,
#   'Pet Clinic': 43,
#   "Elsa and the Nokk's Ice Stable": 44,
#   "Elsa's Wagon Adventure": 45,
#   'Monster Jam Megalodon': 46,
#   'Pet Clinic Ambulance': 47,
#   'Pet Clinic Ambulance_duplicate_1': 212,
#   'Pet Clinic Ambulance_duplicate_2': 377,
#   'Pet Clinic Ambulance_duplicate_3': 542,
#   'Party Llama BeatBox': 48,
#   'Punk Pirate BeatBox': 49,
#   'Elf Club House': 50,
#   'Beach Lifeguard Station': 51,
#   'Candy Mermaid BeatBox': 52,
#   'Telehandler': 53,
#   'Telehandler_duplicate_1': 218,
#   'Telehandler_duplicate_2': 383,
#   'Telehandler_duplicate_3': 548,
#   'Telehandler_duplicate_4': 713,
#   'Telehandler_duplicate_5': 878,
#   'Telehandler_duplicate_6': 1043,
#   'Telehandler_duplicate_7': 1208,
#   'Skid Steer Loader': 54,
#   'Skid Steer Loader_duplicate_1': 219,
#   'Skid Steer Loader_duplicate_2': 384,
#   'Skid Steer Loader_duplicate_3': 549,
#   'Skid Steer Loader_duplicate_4': 714,
#   'Skid Steer Loader_duplicate_5': 879,
#   'Skid Steer Loader_duplicate_6': 1044,
#   'Skid Steer Loader_duplicate_7': 1209,
#   'Skid Steer Loader_duplicate_8': 1374,
#   'Skid Steer Loader_duplicate_9': 1539,
#   'Stunt Plane': 55,
#   'Stunt Plane_duplicate_1': 220,
#   'Stunt Plane_duplicate_2': 385,
#   'Stunt Plane_duplicate_3': 550,
#   'Stunt Plane_duplicate_4': 715,
#   'Stunt Plane_duplicate_5': 880,
#   'Stunt Plane_duplicate_6': 1045,
#   'Stunt Plane_duplicate_7': 1210,
#   'Horse Transporter': 56,
#   'Picnic in the park': 57,
#   'Cement Mixer Truck': 58,
#   'Fire Rescue & Police Chase': 59,
#   'Fire Helicopter': 60,
#   'Fire Helicopter_duplicate_1': 225,
#   'Fire Helicopter_duplicate_2': 390,
#   'Fire Helicopter_duplicate_3': 555,
#   'Fire Helicopter_duplicate_4': 720,
#   'Fire Helicopter_duplicate_5': 885,
#   'Fire Helicopter_duplicate_6': 1050,
#   'Fire Helicopter_duplicate_7': 1215,
#   'Fire Stunt Bike': 61,
#   'Fire Stunt Bike_duplicate_1': 226,
#   'Fire Stunt Bike_duplicate_2': 391,
#   'Fire Stunt Bike_duplicate_3': 556,
#   'Fire Stunt Bike_duplicate_4': 721,
#   'Fire Stunt Bike_duplicate_5': 886,
#   'Fire Stunt Bike_duplicate_6': 1051,
#   'Fire Stunt Bike_duplicate_7': 1216,
#   'Fire Stunt Bike_duplicate_8': 1381,
#   'Fire Stunt Bike_duplicate_9': 1546,
#   'Fire Command Unit': 62,
#   'Creative Building Time': 63,
#   'Bath Time Fun: Floating Animal Island': 64,
#   'Selfie Stunt Bike': 65,
#   'Selfie Stunt Bike_duplicate_1': 230,
#   'Selfie Stunt Bike_duplicate_2': 395,
#   'Selfie Stunt Bike_duplicate_3': 560,
#   'Selfie Stunt Bike_duplicate_4': 725,
#   'Selfie Stunt Bike_duplicate_5': 890,
#   'Selfie Stunt Bike_duplicate_6': 1055,
#   'Selfie Stunt Bike_duplicate_7': 1220,
#   'Selfie Stunt Bike_duplicate_8': 1385,
#   'Selfie Stunt Bike_duplicate_9': 1550,
#   'Chicken Stunt Bike': 66,
#   'Chicken Stunt Bike_duplicate_1': 231,
# ...
#   'Race Car_duplicate_2': 380,
#   'Race Car_duplicate_3': 545,
#   'Race Car_duplicate_4': 710,
#   'Race Car_duplicate_5': 875,
#   'Race Car_duplicate_6': 1040,
#   'Race Car_duplicate_7': 1205,
#   'Stunt Plane': 51,
#   'Stunt Plane_duplicate_1': 216,
#   'Stunt Plane_duplicate_2': 381,
#   'Stunt Plane_duplicate_3': 546,
#   'Stunt Plane_duplicate_4': 711,
#   'Stunt Plane_duplicate_5': 876,
#   'Stunt Plane_duplicate_6': 1041,
#   'Stunt Plane_duplicate_7': 1206,
#   'Fire Helicopter': 52,
#   'Fire Helicopter_duplicate_1': 217,
#   'Fire Helicopter_duplicate_2': 382,
#   'Fire Helicopter_duplicate_3': 547,
#   'Fire Helicopter_duplicate_4': 712,
#   'Fire Helicopter_duplicate_5': 877,
#   'Fire Helicopter_duplicate_6': 1042,
#   'Fire Helicopter_duplicate_7': 1207,
#   'Pet Clinic': 53,
#   'Picnic in the park': 54,
#   'Telehandler': 55,
#   'Telehandler_duplicate_1': 220,
#   'Telehandler_duplicate_2': 385,
#   'Telehandler_duplicate_3': 550,
#   'Telehandler_duplicate_4': 715,
#   'Telehandler_duplicate_5': 880,
#   'Telehandler_duplicate_6': 1045,
#   'Telehandler_duplicate_7': 1210,
#   'Turtle Protection Vehicle': 56,
#   'Turtle Protection Vehicle_duplicate_1': 221,
#   'Turtle Protection Vehicle_duplicate_2': 386,
#   'Turtle Protection Vehicle_duplicate_3': 551,
#   'Pet Clinic Ambulance': 57,
#   'Pet Clinic Ambulance_duplicate_1': 222,
#   'Pet Clinic Ambulance_duplicate_2': 387,
#   'Pet Clinic Ambulance_duplicate_3': 552,
#   'Skid Steer Loader': 58,
#   'Skid Steer Loader_duplicate_1': 223,
#   'Skid Steer Loader_duplicate_2': 388,
#   'Skid Steer Loader_duplicate_3': 553,
#   'Skid Steer Loader_duplicate_4': 718,
#   'Skid Steer Loader_duplicate_5': 883,
#   'Skid Steer Loader_duplicate_6': 1048,
#   'Skid Steer Loader_duplicate_7': 1213,
#   'Skid Steer Loader_duplicate_8': 1378,
#   'Skid Steer Loader_duplicate_9': 1543,
#   'Fire Rescue & Police Chase': 59,
#   "Elsa and the Nokk's Ice Stable": 60,
#   "Jay's Spinjitzu Ninja Training": 61,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 226,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 391,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 556,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 721,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 886,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1051,
#   "Lloyd's Spinjitzu Ninja Training": 62,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 227,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 392,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 557,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 722,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 887,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1052,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1217,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1382,
#   'Fire Stunt Bike': 63,
#   'Fire Stunt Bike_duplicate_1': 228,
#   'Fire Stunt Bike_duplicate_2': 393,
#   'Fire Stunt Bike_duplicate_3': 558,
#   'Fire Stunt Bike_duplicate_4': 723,
#   'Fire Stunt Bike_duplicate_5': 888,
#   'Fire Stunt Bike_duplicate_6': 1053,
#   'Fire Stunt Bike_duplicate_7': 1218,
#   'Fire Stunt Bike_duplicate_8': 1383,
#   'Fire Stunt Bike_duplicate_9': 1548,
#   'Chicken Stunt Bike': 64,
#   'Chicken Stunt Bike_duplicate_1': 229,
#   'Chicken Stunt Bike_duplicate_2': 394,
#   'Chicken Stunt Bike_duplicate_3': 559,
#   'Chicken Stunt Bike_duplicate_4': 724,
#   'Chicken Stunt Bike_duplicate_5': 889,
#   'Chicken Stunt Bike_duplicate_6': 1054,
#   'Chicken Stunt Bike_duplicate_7': 1219,
#   'Chicken Stunt Bike_duplicate_8': 1384,
#   'Chicken Stunt Bike_duplicate_9': 1549,
#   'Creative Building Time': 65,
#   'Selfie Stunt Bike': 66,
#   'Selfie Stunt Bike_duplicate_1': 231,
#   'Selfie Stunt Bike_duplicate_2': 396,
#   'Selfie Stunt Bike_duplicate_3': 561,
#   'Selfie Stunt Bike_duplicate_4': 726,
#   'Selfie Stunt Bike_duplicate_5': 891,
#   'Selfie Stunt Bike_duplicate_6': 1056,
#   'Selfie Stunt Bike_duplicate_7': 1221,
#   'Selfie Stunt Bike_duplicate_8': 1386,
#   'Selfie Stunt Bike_duplicate_9': 1551},
#  'danny316p': {'Medieval Castle': 0,
#   'Creative Building Time': 1,
#   'Ice Cream Truck Police Chase': 2,
#   'Street Racer': 3,
#   'Dolphin and Turtle': 4,
#   'Dolphin and Turtle_duplicate_1': 169,
#   'Dolphin and Turtle_duplicate_2': 334,
#   'Dolphin and Turtle_duplicate_3': 499,
#   "Elsa's Wagon Adventure": 5,
#   'Forest House': 6,
#   'Magical Caravan': 7,
#   'Picnic in the park': 8,
#   'Message Board': 9,
#   'Lots of DOTS': 10,
#   'Lots of DOTS_duplicate_1': 175,
#   'Pet Playground': 11,
#   'Pet Clinic': 12,
#   'Turtle Protection Vehicle': 13,
#   'Turtle Protection Vehicle_duplicate_1': 178,
#   'Turtle Protection Vehicle_duplicate_2': 343,
#   'Turtle Protection Vehicle_duplicate_3': 508,
#   'Tree-Planting Vehicle': 14,
#   'Creative Party Kit': 15,
#   'Creative Party Kit_duplicate_1': 180,
#   'Fantasy Forest Creatures': 16,
#   'Holiday Camper Van': 17,
#   "Elsa and the Nokk's Ice Stable": 18,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 19,
#   'Fire Command Unit': 20,
#   'Bath Time Fun: Floating Animal Island': 21,
#   'Stunt Show Arena': 22,
#   'Fire Rescue & Police Chase': 23,
#   'Beach Lifeguard Station': 24,
#   'Telehandler': 25,
#   'Telehandler_duplicate_1': 190,
#   'Telehandler_duplicate_2': 355,
#   'Telehandler_duplicate_3': 520,
#   'Telehandler_duplicate_4': 685,
#   'Telehandler_duplicate_5': 850,
#   'Telehandler_duplicate_6': 1015,
#   'Telehandler_duplicate_7': 1180,
#   'Horse Transporter': 26,
#   'Heartlake City School': 27,
#   'Fire Stunt Bike': 28,
#   'Fire Stunt Bike_duplicate_1': 193,
#   'Fire Stunt Bike_duplicate_2': 358,
#   'Fire Stunt Bike_duplicate_3': 523,
#   'Fire Stunt Bike_duplicate_4': 688,
#   'Fire Stunt Bike_duplicate_5': 853,
#   'Fire Stunt Bike_duplicate_6': 1018,
#   'Fire Stunt Bike_duplicate_7': 1183,
#   'Fire Stunt Bike_duplicate_8': 1348,
#   'Fire Stunt Bike_duplicate_9': 1513,
#   "Lloyd's Spinjitzu Ninja Training": 29,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 194,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 359,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 524,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 689,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 854,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1019,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1184,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1349,
#   "Jay's Spinjitzu Ninja Training": 30,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 195,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 360,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 525,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 690,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 855,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1020,
#   'Safari Wildlife Tree House': 31,
#   'Hogwarts™ Moment: Transfiguration Class': 32,
#   'Hogwarts™ Moment: Potions Class': 33,
#   'Creative Transparent Bricks': 34,
#   'Bricks and Wheels': 35,
#   'Party Llama BeatBox': 36,
#   'Around the World': 37,
#   'Around the World_duplicate_1': 202,
#   'Motorcycle': 39,
#   'Motorcycle_duplicate_1': 204,
#   'Motorcycle_duplicate_2': 369,
#   'Motorcycle_duplicate_3': 534,
#   'Motorcycle_duplicate_4': 699,
#   'Motorcycle_duplicate_5': 864,
#   'Motorcycle_duplicate_6': 1029,
#   'Motorcycle_duplicate_7': 1194,
#   'Creative Building Bricks': 40,
#   'Creative Monsters': 41,
#   'Creative Monsters_duplicate_1': 206,
#   'Creative Monsters_duplicate_2': 371,
#   'Creative Monsters_duplicate_3': 536,
#   'Creative Ocean Fun': 42,
#   'Chicken Stunt Bike': 43,
#   'Chicken Stunt Bike_duplicate_1': 208,
#   'Chicken Stunt Bike_duplicate_2': 373,
#   'Chicken Stunt Bike_duplicate_3': 538,
#   'Chicken Stunt Bike_duplicate_4': 703,
#   'Chicken Stunt Bike_duplicate_5': 868,
#   'Chicken Stunt Bike_duplicate_6': 1033,
#   'Chicken Stunt Bike_duplicate_7': 1198,
#   'Chicken Stunt Bike_duplicate_8': 1363,
#   'Chicken Stunt Bike_duplicate_9': 1528,
#   'Skid Steer Loader': 44,
#   'Skid Steer Loader_duplicate_1': 209,
#   'Skid Steer Loader_duplicate_2': 374,
#   'Skid Steer Loader_duplicate_3': 539,
#   'Skid Steer Loader_duplicate_4': 704,
#   'Skid Steer Loader_duplicate_5': 869,
#   'Skid Steer Loader_duplicate_6': 1034,
#   'Skid Steer Loader_duplicate_7': 1199,
#   'Skid Steer Loader_duplicate_8': 1364,
#   'Skid Steer Loader_duplicate_9': 1529,
#   'Off-road Buggy': 45,
#   'Supersonic-jet': 46,
#   'Cement Mixer Truck': 47,
#   'Monster Jam El Toro Loco': 48,
#   'Punk Pirate BeatBox': 49,
#   'Pet Clinic Ambulance': 50,
#   'Pet Clinic Ambulance_duplicate_1': 215,
#   'Pet Clinic Ambulance_duplicate_2': 380,
#   'Pet Clinic Ambulance_duplicate_3': 545,
#   'Snowtrooper Battle Pack': 51,
#   'Alien DJ BeatBox': 52,
#   'Candy Mermaid BeatBox': 53,
#   'Elf Club House': 54,
#   'Stunt Plane': 55,
#   'Stunt Plane_duplicate_1': 220,
#   'Stunt Plane_duplicate_2': 385,
#   'Stunt Plane_duplicate_3': 550,
#   'Stunt Plane_duplicate_4': 715,
#   'Stunt Plane_duplicate_5': 880,
#   'Stunt Plane_duplicate_6': 1045,
#   'Stunt Plane_duplicate_7': 1210,
#   'Fire Helicopter': 56,
#   'Fire Helicopter_duplicate_1': 221,
#   'Fire Helicopter_duplicate_2': 386,
#   'Fire Helicopter_duplicate_3': 551,
#   'Fire Helicopter_duplicate_4': 716,
#   'Fire Helicopter_duplicate_5': 881,
#   'Fire Helicopter_duplicate_6': 1046,
#   'Fire Helicopter_duplicate_7': 1211,
#   'Dark Trooper Attack': 57,
#   'Resistance X-Wing™': 58,
#   'Bricks and Functions': 59,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 60,
#   'Fire Dragon Attack': 61,
#   'Selfie Stunt Bike': 62,
#   'Selfie Stunt Bike_duplicate_1': 227,
#   'Selfie Stunt Bike_duplicate_2': 392,
#   'Selfie Stunt Bike_duplicate_3': 557,
#   'Selfie Stunt Bike_duplicate_4': 722,
#   'Selfie Stunt Bike_duplicate_5': 887,
#   'Selfie Stunt Bike_duplicate_6': 1052,
#   'Selfie Stunt Bike_duplicate_7': 1217,
#   'Selfie Stunt Bike_duplicate_8': 1382,
#   'Selfie Stunt Bike_duplicate_9': 1547,
#   'Caravan Family Holiday': 63,
#   'Monster Jam Megalodon': 64,
#   'Cute Banana Pen Holder': 65,
#   'Race Car': 66,
#   'Race Car_duplicate_1': 231,
#   'Race Car_duplicate_2': 396,
#   'Race Car_duplicate_3': 561,
#   'Race Car_duplicate_4': 726,
#   'Race Car_duplicate_5': 891,
#   'Race Car_duplicate_6': 1056,
#   'Race Car_duplicate_7': 1221},
#  'Copy of YourName': {'Fire Command Unit': 0,
#   'Motorcycle': 1,
#   'Motorcycle_duplicate_1': 166,
#   'Motorcycle_duplicate_2': 331,
#   'Motorcycle_duplicate_3': 496,
#   'Motorcycle_duplicate_4': 661,
#   'Motorcycle_duplicate_5': 826,
#   'Motorcycle_duplicate_6': 991,
#   'Motorcycle_duplicate_7': 1156,
#   'Skid Steer Loader': 2,
#   'Skid Steer Loader_duplicate_1': 167,
#   'Skid Steer Loader_duplicate_2': 332,
#   'Skid Steer Loader_duplicate_3': 497,
#   'Skid Steer Loader_duplicate_4': 662,
#   'Skid Steer Loader_duplicate_5': 827,
#   'Skid Steer Loader_duplicate_6': 992,
#   'Skid Steer Loader_duplicate_7': 1157,
#   'Skid Steer Loader_duplicate_8': 1322,
#   'Skid Steer Loader_duplicate_9': 1487,
#   'Elf Club House': 3,
#   'Caravan Family Holiday': 4,
#   'Hogwarts™ Moment: Potions Class': 5,
#   'Fire Dragon Attack': 6,
#   'Supersonic-jet': 7,
#   'Hogwarts™ Moment: Transfiguration Class': 8,
#   'Dark Trooper Attack': 9,
#   'Medieval Castle': 10,
#   'Telehandler': 11,
#   'Telehandler_duplicate_1': 176,
#   'Telehandler_duplicate_2': 341,
#   'Telehandler_duplicate_3': 506,
#   'Telehandler_duplicate_4': 671,
#   'Telehandler_duplicate_5': 836,
#   'Telehandler_duplicate_6': 1001,
#   'Telehandler_duplicate_7': 1166,
#   'Monster Jam El Toro Loco': 12,
#   'Alien DJ BeatBox': 13,
#   'Off-road Buggy': 14,
#   'Safari Wildlife Tree House': 15,
#   'Dolphin and Turtle': 16,
#   'Dolphin and Turtle_duplicate_1': 181,
#   'Dolphin and Turtle_duplicate_2': 346,
#   'Dolphin and Turtle_duplicate_3': 511,
#   'Fantasy Forest Creatures': 17,
#   'Lots of DOTS': 18,
#   'Lots of DOTS_duplicate_1': 183,
#   'Ice Cream Truck Police Chase': 19,
#   'Message Board': 20,
#   'Party Llama BeatBox': 21,
#   'Punk Pirate BeatBox': 22,
#   'Holiday Camper Van': 23,
#   'Monster Jam Megalodon': 24,
#   'Turtle Protection Vehicle': 25,
#   'Turtle Protection Vehicle_duplicate_1': 190,
#   'Turtle Protection Vehicle_duplicate_2': 355,
#   'Turtle Protection Vehicle_duplicate_3': 520,
#   'AT-AT™ vs. Tauntaun™ Microfighters': 26,
#   "Jay's Spinjitzu Ninja Training": 27,
#   "Jay's Spinjitzu Ninja Training_duplicate_1": 192,
#   "Jay's Spinjitzu Ninja Training_duplicate_2": 357,
#   "Jay's Spinjitzu Ninja Training_duplicate_3": 522,
#   "Jay's Spinjitzu Ninja Training_duplicate_4": 687,
#   "Jay's Spinjitzu Ninja Training_duplicate_5": 852,
#   "Jay's Spinjitzu Ninja Training_duplicate_6": 1017,
#   "Lloyd's Spinjitzu Ninja Training": 28,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1": 193,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2": 358,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3": 523,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4": 688,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5": 853,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6": 1018,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7": 1183,
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8": 1348,
#   'Picnic in the park': 29,
#   'Beach Lifeguard Station': 30,
#   'Fire Rescue & Police Chase': 31,
#   'Chicken Stunt Bike': 32,
#   'Chicken Stunt Bike_duplicate_1': 197,
#   'Chicken Stunt Bike_duplicate_2': 362,
#   'Chicken Stunt Bike_duplicate_3': 527,
#   'Chicken Stunt Bike_duplicate_4': 692,
#   'Chicken Stunt Bike_duplicate_5': 857,
#   'Chicken Stunt Bike_duplicate_6': 1022,
#   'Chicken Stunt Bike_duplicate_7': 1187,
#   'Chicken Stunt Bike_duplicate_8': 1352,
#   'Chicken Stunt Bike_duplicate_9': 1517,
#   'Stunt Show Arena': 33,
#   'Bricks and Wheels': 34,
#   'Tree-Planting Vehicle': 35,
#   'Creative Building Bricks': 36,
#   'Creative Monsters': 37,
#   'Creative Monsters_duplicate_1': 202,
#   'Creative Monsters_duplicate_2': 367,
#   'Creative Monsters_duplicate_3': 532,
#   'Creative Ocean Fun': 38,
#   'Bricks and Functions': 39,
#   'Forest House': 40,
#   'Candy Mermaid BeatBox': 41,
#   'Around the World': 42,
#   'Around the World_duplicate_1': 207,
#   'Cement Mixer Truck': 44,
#   'Creative Transparent Bricks': 45,
#   "Elsa's Wagon Adventure": 46,
#   'Heartlake City School': 47,
#   'Magical Caravan': 48,
#   'Pet Clinic Ambulance': 49,
#   'Pet Clinic Ambulance_duplicate_1': 214,
#   'Pet Clinic Ambulance_duplicate_2': 379,
#   'Pet Clinic Ambulance_duplicate_3': 544,
#   'Selfie Stunt Bike': 50,
#   'Selfie Stunt Bike_duplicate_1': 215,
#   'Selfie Stunt Bike_duplicate_2': 380,
#   'Selfie Stunt Bike_duplicate_3': 545,
#   'Selfie Stunt Bike_duplicate_4': 710,
#   'Selfie Stunt Bike_duplicate_5': 875,
#   'Selfie Stunt Bike_duplicate_6': 1040,
#   'Selfie Stunt Bike_duplicate_7': 1205,
#   'Selfie Stunt Bike_duplicate_8': 1370,
#   'Selfie Stunt Bike_duplicate_9': 1535,
#   'Fire Stunt Bike': 51,
#   'Fire Stunt Bike_duplicate_1': 216,
#   'Fire Stunt Bike_duplicate_2': 381,
#   'Fire Stunt Bike_duplicate_3': 546,
#   'Fire Stunt Bike_duplicate_4': 711,
#   'Fire Stunt Bike_duplicate_5': 876,
#   'Fire Stunt Bike_duplicate_6': 1041,
#   'Fire Stunt Bike_duplicate_7': 1206,
#   'Fire Stunt Bike_duplicate_8': 1371,
#   'Fire Stunt Bike_duplicate_9': 1536,
#   'Creative Party Kit': 52,
#   'Creative Party Kit_duplicate_1': 217,
#   'Street Racer': 53,
#   "Elsa and the Nokk's Ice Stable": 54,
#   'Resistance X-Wing™': 55,
#   'Horse Transporter': 56,
#   'Stunt Plane': 57,
#   'Stunt Plane_duplicate_1': 222,
#   'Stunt Plane_duplicate_2': 387,
#   'Stunt Plane_duplicate_3': 552,
#   'Stunt Plane_duplicate_4': 717,
#   'Stunt Plane_duplicate_5': 882,
#   'Stunt Plane_duplicate_6': 1047,
#   'Stunt Plane_duplicate_7': 1212,
#   'Race Car': 58,
#   'Race Car_duplicate_1': 223,
#   'Race Car_duplicate_2': 388,
#   'Race Car_duplicate_3': 553,
#   'Race Car_duplicate_4': 718,
#   'Race Car_duplicate_5': 883,
#   'Race Car_duplicate_6': 1048,
#   'Race Car_duplicate_7': 1213,
#   'Snowtrooper Battle Pack': 59,
#   'Cute Banana Pen Holder': 60,
#   'Creative Building Time': 61,
#   'Bath Time Fun: Floating Animal Island': 62,
#   'Pet Clinic': 63,
#   'Pet Playground': 64,
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures": 65,
#   'Fire Helicopter': 66,
#   'Fire Helicopter_duplicate_1': 231,
#   'Fire Helicopter_duplicate_2': 396,
#   'Fire Helicopter_duplicate_3': 561,
#   'Fire Helicopter_duplicate_4': 726,
#   'Fire Helicopter_duplicate_5': 891,
#   'Fire Helicopter_duplicate_6': 1056,
#   'Fire Helicopter_duplicate_7': 1221}}

# %%
matching = MatchingGenerator.generate_matching(ranks, strategy='RMA')
matching
# Out:
# {'Primus': ['Hogwarts™ Moment: Potions Class',
#   'Candy Mermaid BeatBox',
#   'Turtle Protection Vehicle',
#   'Telehandler_duplicate_2',
#   'Telehandler_duplicate_4',
#   'Chicken Stunt Bike_duplicate_6'],
#  'Voxumo': ['Caravan Family Holiday',
#   'Holiday Camper Van',
#   'Chicken Stunt Bike',
#   'Chicken Stunt Bike_duplicate_5',
#   'Motorcycle_duplicate_7',
#   "Jay's Spinjitzu Ninja Training_duplicate_6"],
#  'MSEP': ['Medieval Castle',
#   'Fire Rescue & Police Chase',
#   'Horse Transporter',
#   'Stunt Plane_duplicate_2',
#   'Selfie Stunt Bike_duplicate_4',
#   "Jay's Spinjitzu Ninja Training_duplicate_2"],
#  'FuzzE': ['Bath Time Fun: Floating Animal Island',
#   'Cute Banana Pen Holder',
#   'Motorcycle_duplicate_1',
#   'Skid Steer Loader_duplicate_3',
#   'Stunt Plane_duplicate_6',
#   'Telehandler_duplicate_6'],
#  'dviddy': ['Fantasy Forest Creatures',
#   'Magical Caravan',
#   'Skid Steer Loader_duplicate_1',
#   'Telehandler_duplicate_3',
#   'Race Car_duplicate_4',
#   "Lloyd's Spinjitzu Ninja Training_duplicate_4"],
#  'awesomenessborn': ['Dark Trooper Attack',
#   'Fire Helicopter_duplicate_3',
#   'Turtle Protection Vehicle_duplicate_2',
#   'Selfie Stunt Bike_duplicate_2',
#   'Motorcycle_duplicate_5',
#   'Motorcycle_duplicate_2'],
#  'woomyworld': ['Fire Dragon Attack',
#   "Ariel, Belle, Cinderella and Tiana's Storybook Adventures",
#   'Skid Steer Loader_duplicate_7',
#   'Telehandler_duplicate_7',
#   "Jay's Spinjitzu Ninja Training_duplicate_5",
#   'Fire Helicopter_duplicate_5'],
#  'ChocolateFrogs': ['Alien DJ BeatBox',
#   'Bricks and Functions',
#   "Jay's Spinjitzu Ninja Training_duplicate_4",
#   'Motorcycle_duplicate_4',
#   'Chicken Stunt Bike_duplicate_3',
#   'Fire Helicopter_duplicate_6'],
#  'Calcifer': ['Elf Club House',
#   'Race Car',
#   'Stunt Plane',
#   'Stunt Plane_duplicate_7',
#   "Lloyd's Spinjitzu Ninja Training_duplicate_8",
#   'Selfie Stunt Bike_duplicate_6'],
#  'maxhowell': ['Creative Party Kit',
#   'Bricks and Wheels',
#   'Creative Ocean Fun',
#   'Chicken Stunt Bike_duplicate_1',
#   'Creative Party Kit_duplicate_1',
#   'Fire Stunt Bike_duplicate_8'],
#  'Kanakalackin': ['Motorcycle',
#   'Punk Pirate BeatBox',
#   'Telehandler_duplicate_5',
#   'Pet Clinic Ambulance_duplicate_3',
#   'Fire Stunt Bike_duplicate_2',
#   'Stunt Plane_duplicate_3'],
#  'Optimus Convoy': ['Creative Building Time',
#   "Lloyd's Spinjitzu Ninja Training_duplicate_3",
#   'Pet Clinic Ambulance',
#   'Fire Stunt Bike_duplicate_1',
#   'Dolphin and Turtle_duplicate_3',
#   'Motorcycle_duplicate_6'],
#  'Bionic_': ['Monster Jam El Toro Loco',
#   "Elsa and the Nokk's Ice Stable",
#   'Fire Helicopter',
#   "Lloyd's Spinjitzu Ninja Training_duplicate_7",
#   'Chicken Stunt Bike_duplicate_2',
#   'Stunt Plane_duplicate_4'],
#  'Lord Oblivion': ['Street Racer',
#   'Fire Stunt Bike_duplicate_9',
#   'Selfie Stunt Bike_duplicate_3',
#   'Chicken Stunt Bike_duplicate_7',
#   'Fire Stunt Bike_duplicate_4',
#   "Lloyd's Spinjitzu Ninja Training_duplicate_6"],
#  'Ta-metru_defender': ['Heartlake City School',
#   'Safari Wildlife Tree House',
#   'Pet Clinic',
#   "Lloyd's Spinjitzu Ninja Training_duplicate_5",
#   'Chicken Stunt Bike_duplicate_4',
#   'Fire Helicopter_duplicate_2'],
#  'PoorDisadvantaged': ["Lloyd's Spinjitzu Ninja Training",
#   "Jay's Spinjitzu Ninja Training",
#   'Forest House',
#   'Race Car_duplicate_7',
#   "Lloyd's Spinjitzu Ninja Training_duplicate_1",
#   'Fire Stunt Bike_duplicate_3'],
#  'Margit': ['Creative Building Bricks',
#   'Around the World',
#   'Race Car_duplicate_1',
#   "Lloyd's Spinjitzu Ninja Training_duplicate_2",
#   'Around the World_duplicate_1',
#   'Dolphin and Turtle_duplicate_2'],
#  'SilvakTheMocist': ['Monster Jam Megalodon',
#   'Lots of DOTS',
#   'Creative Monsters',
#   'Selfie Stunt Bike_duplicate_1',
#   'Lots of DOTS_duplicate_1',
#   'Creative Monsters_duplicate_1'],
#  'Princess Mittens': ['Telehandler',
#   'Party Llama BeatBox',
#   'Selfie Stunt Bike_duplicate_9',
#   'Creative Monsters_duplicate_2',
#   'Telehandler_duplicate_1',
#   'Race Car_duplicate_3'],
#  'Sprinkle Otter': ['Snowtrooper Battle Pack',
#   'Hogwarts™ Moment: Transfiguration Class',
#   'Selfie Stunt Bike',
#   'Fire Stunt Bike',
#   "Jay's Spinjitzu Ninja Training_duplicate_1",
#   'Fire Helicopter_duplicate_1'],
#  'JrMasterModelBuilder': ['Stunt Show Arena',
#   'Beach Lifeguard Station',
#   'Skid Steer Loader_duplicate_5',
#   'Race Car_duplicate_5',
#   'Fire Helicopter_duplicate_4',
#   'Fire Stunt Bike_duplicate_7'],
#  'The Underscored Double': ['Cement Mixer Truck',
#   'Tree-Planting Vehicle',
#   'Pet Playground',
#   'Turtle Protection Vehicle_duplicate_3',
#   'Chicken Stunt Bike_duplicate_9',
#   'Pet Clinic Ambulance_duplicate_2'],
#  'Renzari': ['Dolphin and Turtle',
#   'Resistance X-Wing™',
#   'Skid Steer Loader_duplicate_4',
#   'Race Car_duplicate_2',
#   'Dolphin and Turtle_duplicate_1',
#   'Fire Helicopter_duplicate_7'],
#  'Aiden.Builds': ['Supersonic-jet',
#   'Message Board',
#   'Selfie Stunt Bike_duplicate_7',
#   'Fire Stunt Bike_duplicate_5',
#   'Pet Clinic Ambulance_duplicate_1',
#   "Jay's Spinjitzu Ninja Training_duplicate_3"],
#  'Ziontyro': ['Creative Transparent Bricks',
#   'Skid Steer Loader_duplicate_8',
#   'Motorcycle_duplicate_3',
#   'Selfie Stunt Bike_duplicate_5',
#   'Skid Steer Loader_duplicate_9',
#   'Skid Steer Loader_duplicate_2'],
#  'alex_mocs': ['AT-AT™ vs. Tauntaun™ Microfighters',
#   'Off-road Buggy',
#   'Skid Steer Loader_duplicate_6',
#   'Stunt Plane_duplicate_1',
#   'Selfie Stunt Bike_duplicate_8',
#   'Creative Monsters_duplicate_3'],
#  'danny316p': ['Ice Cream Truck Police Chase',
#   "Elsa's Wagon Adventure",
#   'Picnic in the park',
#   'Chicken Stunt Bike_duplicate_8',
#   'Turtle Protection Vehicle_duplicate_1'],
#  'Copy of YourName': ['Fire Command Unit',
#   'Skid Steer Loader',
#   'Stunt Plane_duplicate_5',
#   'Fire Stunt Bike_duplicate_6',
#   'Race Car_duplicate_6']}

# %%
profile = Profile.compute_profile_from_result(ranks, matching)
readable_profile = {i: profile[i] for i in range(len(profile)) if profile[i] != 0}
readable_profile
# Out:
# {0: 13,
#  1: 7,
#  2: 7,
#  3: 3,
#  4: 4,
#  5: 2,
#  6: 5,
#  7: 3,
#  8: 4,
#  9: 1,
#  10: 3,
#  11: 1,
#  12: 4,
#  13: 1,
#  14: 1,
#  18: 1,
#  21: 1,
#  25: 1,
#  30: 1,
#  34: 1,
#  42: 1,
#  57: 1,
#  66: 7,
#  68: 1,
#  69: 1,
#  71: 1,
#  73: 2,
#  74: 1,
#  79: 2,
#  80: 2,
#  82: 1,
#  84: 1,
#  85: 1,
#  87: 4,
#  88: 1,
#  89: 2,
#  91: 2,
#  95: 1,
#  96: 1,
#  97: 2,
#  99: 1,
#  100: 1,
#  101: 2,
#  102: 1,
#  103: 1,
#  104: 1,
#  105: 2,
#  107: 1,
#  109: 1,
#  110: 1,
#  112: 1,
#  113: 2,
#  114: 2,
#  115: 2,
#  116: 1,
#  117: 3,
#  118: 1,
#  119: 1,
#  123: 1,
#  126: 2,
#  127: 2,
#  129: 2,
#  130: 2,
#  132: 2,
#  133: 1,
#  137: 2,
#  138: 1,
#  139: 1,
#  140: 1,
#  141: 2,
#  143: 2,
#  144: 1,
#  145: 1,
#  147: 1,
#  149: 1,
#  150: 2,
#  151: 2,
#  152: 2,
#  153: 1,
#  154: 1,
#  157: 1,
#  158: 1,
#  159: 1,
#  161: 2,
#  162: 1,
#  163: 1,
#  164: 2}

# %%
with open('matching.json', 'w+') as f:
    f.write(json.dumps(matching, indent=2))

# %%
with open('ranks.json', 'w+') as f:
    for applicant in ranks:
        for job in ranks[applicant]:
            ranks[applicant][job] = int(ranks[applicant][job])
    
    f.write(json.dumps(ranks, indent=2))
